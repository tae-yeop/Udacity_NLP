# %% [markdown]
# # Project: Part of Speech Tagging with Hidden Markov Models
# ---
# ### Introduction
#
# Part of speech tagging is the process of determining the syntactic category of a word from the words in its surrounding context. It is often used to help disambiguate natural language phrases because it can be done quickly with high accuracy. Tagging can be used for many NLP tasks like determining correct pronunciation during speech synthesis (for example, _dis_-count as a noun vs dis-_count_ as a verb), for information retrieval, and for word sense disambiguation.
#
# In this notebook, you'll use the [Pomegranate](http://pomegranate.readthedocs.io/) library to build a hidden Markov model for part of speech tagging using a "universal" tagset. Hidden Markov models have been able to achieve [>96% tag accuracy with larger tagsets on realistic text corpora](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf). Hidden Markov models have also been used for speech recognition and speech generation, machine translation, gene recognition for bioinformatics, and human gesture recognition for computer vision, and more.
#
# ![](_post-hmm.png)
#
# The notebook already contains some code to get you started. You only need to add some new functionality in the areas indicated to complete the project; you will not need to modify the included code beyond what is requested. Sections that begin with **'IMPLEMENTATION'** in the header indicate that you must provide code in the block that follows. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You must then **export the notebook** by running the last cell in the notebook, or by using the menu above and navigating to **File -> Download as -> HTML (.html)** Your submissions should include both the `html` and `ipynb` files.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Code and Markdown cells can be executed using the `Shift + Enter` keyboard shortcut. Markdown cells can be edited by double-clicking the cell to enter edit mode.
# </div>

# %% [markdown]
# ### The Road Ahead
# You must complete Steps 1-3 below to pass the project. The section on Step 4 includes references & resources you can use to further explore HMM taggers.
#
# - [Step 1](#Step-1:-Read-and-preprocess-the-dataset): Review the provided interface to load and access the text corpus
# - [Step 2](#Step-2:-Build-a-Most-Frequent-Class-tagger): Build a Most Frequent Class tagger to use as a baseline
# - [Step 3](#Step-3:-Build-an-HMM-tagger): Build an HMM Part of Speech tagger and compare to the MFC baseline
# - [Step 4](#Step-4:-[Optional]-Improving-model-performance): (Optional) Improve the HMM tagger

# %% [markdown]
# <div class="alert alert-block alert-warning">
# **Note:** Make sure you have selected a **Python 3** kernel in Workspaces or the hmm-tagger conda environment if you are running the Jupyter server on your own machine.
# </div>

# %%
# Jupyter "magic methods" -- only need to be run once per kernel restart
# %load_ext autoreload
# %aimport helpers, tests
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import python modules -- this cell needs to be run again if you make changes to any of the files
import matplotlib.pyplot as plt
import numpy as np

from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict
from helpers import show_model, Dataset
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-29eb4ce4990a> in <module>()
#       7 from collections import Counter, defaultdict
#       8 from helpers import show_model, Dataset
# ----> 9 from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
#
# ImportError: No module named 'pomegranate'

# %% [markdown]
# ## Step 1: Read and preprocess the dataset
# ---
# We'll start by reading in a text corpus and splitting it into a training and testing dataset. The data set is a copy of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus) (originally from the [NLTK](https://www.nltk.org/) library) that has already been pre-processed to only include the [universal tagset](https://arxiv.org/pdf/1104.2086.pdf). You should expect to get slightly higher accuracy using this simplified tagset than the same model would achieve on a larger tagset like the full [Penn treebank tagset](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html), but the process you'll follow would be the same.
#
# The `Dataset` class provided in helpers.py will read and parse the corpus. You can generate your own datasets compatible with the reader by writing them to the following format. The dataset is stored in plaintext as a collection of words and corresponding tags. Each sentence starts with a unique identifier on the first line, followed by one tab-separated word/tag pair on each following line. Sentences are separated by a single blank line.
#
# Example from the Brown corpus.
# ```
# b100-38532
# Perhaps	ADV
# it	PRON
# was	VERB
# right	ADJ
# ;	.
# ;	.
#
# b100-35577
# ...
# ```

# %%
data = Dataset("tags-universal.txt", "brown-universal.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 57340 sentences in the corpus.
# There are 45872 sentences in the training set.
# There are 11468 sentences in the testing set.

# %%
type(data.training_set)
# Out:
# helpers.Subset

# %%
data.training_set[0]
# Out:
# {'b100-35433': Sentence(words=('Whenever', 'artists', ',', 'indeed', ',', 'turned', 'to', 'actual', 'representations', 'or', 'molded', 'three-dimensional', 'figures', ',', 'which', 'were', 'rare', 'down', 'to', '800', 'B.C.', ',', 'they', 'tended', 'to', 'reflect', 'reality', '(', 'see', 'Plate', '6a', ',', '9b', ')', ';', ';'), tags=('ADV', 'NOUN', '.', 'ADV', '.', 'VERB', 'ADP', 'ADJ', 'NOUN', 'CONJ', 'VERB', 'ADJ', 'NOUN', '.', 'DET', 'VERB', 'ADJ', 'PRT', 'ADP', 'NUM', 'NOUN', '.', 'PRON', 'VERB', 'PRT', 'VERB', 'NOUN', '.', 'VERB', 'NOUN', 'NUM', '.', 'NUM', '.', '.', '.')),
#  'b100-16721': Sentence(words=('For', 'almost', 'two', 'months', ',', 'the', 'defendant', 'and', 'the', 'world', 'heard', 'from', 'individuals', 'escaped', 'from', 'the', 'grave', 'about', 'fathers', 'and', 'mothers', ',', 'graybeards', ',', 'adolescents', ',', 'babies', ',', 'starved', ',', 'beaten', 'to', 'death', ',', 'strangled', ',', 'machine-gunned', ',', 'gassed', ',', 'burned', '.'), tags=('ADP', 'ADV', 'NUM', 'NOUN', '.', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'VERB', '.', 'VERB', 'ADP', 'NOUN', '.', 'VERB', '.', 'VERB', '.', 'VERB', '.', 'VERB', '.')),
#  'b100-5902': Sentence(words=('Clearer', 'meaning'), tags=('ADJ', 'NOUN')),
#  'b100-45820': Sentence(words=('Yes', ',', 'gentlemen', ',', 'I', 'am', 'getting', 'to', 'the', 'point', ',', 'to', 'my', 'point', '.'), tags=('ADV', '.', 'NOUN', '.', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-9070': Sentence(words=('About', 'the', 'same', 'time', 'the', 'Alleghenies', 'and', 'Poconos', 'in', 'Pennsylvania', 'are', 'magnificent', '--', 'Renovo', 'holds', 'its', 'annual', 'Flaming', 'Foliage', 'Festival', 'on', 'Oct.', '14', ',', '15', '.'), tags=('ADV', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADJ', '.', 'NOUN', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NUM', '.', 'NUM', '.')),
#  'b100-45477': Sentence(words=("There's", 'no', 'doubt', 'this', 'Tim', 'sneaked', 'back', 'and', 'killed', 'Mrs.', 'Buck', '.'), tags=('PRT', 'DET', 'NOUN', 'DET', 'NOUN', 'VERB', 'ADV', 'CONJ', 'VERB', 'NOUN', 'NOUN', '.')),
#  'b100-18878': Sentence(words=('The', "cowboy's", 'humorous', 'name', 'for', 'a', 'cow', "givin'", 'milk', 'was', 'a', '``', 'milk', 'pitcher', "''", '.'), tags=('DET', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', 'VERB', 'DET', '.', 'NOUN', 'NOUN', '.', '.')),
#  'b100-21430': Sentence(words=('It', 'is', 'therefore', 'not', 'surprising', 'that', 'they', 'resist', 'the', 'lure', 'of', 'marriage', 'and', 'the', 'trap', 'of', 'domesticity', ',', 'for', 'like', 'cats', 'they', 'are', 'determined', 'not', 'to', 'tame', 'their', 'sexual', 'energy', '.'), tags=('PRON', 'VERB', 'ADV', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-30529': Sentence(words=('A', 'shielded', 'thermocouple', 'was', 'used', 'to', 'measure', 'the', 'upstream', 'temperature', 'of', 'the', 'transpiring', 'gas', '.'), tags=('DET', 'VERB', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.')),
#  'b100-10606': Sentence(words=('The', 'ideals', 'of', 'the', 'country', 'were', 'deeply', 'indebted', 'to', 'the', 'Protestantism', 'of', 'the', 'older', 'stock', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-51259': Sentence(words=('Matsuo', 'laughed', ',', 'slung', 'the', 'rifle', '.'), tags=('NOUN', 'VERB', '.', 'VERB', 'DET', 'NOUN', '.')),
#  'b100-39459': Sentence(words=('Rousseau', 'asked', '.'), tags=('NOUN', 'VERB', '.')),
#  'b100-1669': Sentence(words=('Dave', 'Trager', ',', 'who', 'is', 'quite', 'a', 'showman', 'and', 'boss', 'of', "Chicago's", 'new', 'pro', 'basketball', 'Packers', ',', 'is', 'debuting', 'a', 'new', 'International', 'club', ',', 'for', 'the', 'exclusive', 'use', 'of', 'season', 'ticket', 'holders', ',', 'in', 'the', 'Stock', 'Yards', 'Inn', '.'), tags=('NOUN', 'NOUN', '.', 'PRON', 'VERB', 'PRT', 'DET', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.')),
#  'b100-56077': Sentence(words=('While', 'he', 'waited', 'in', 'the', 'living', 'room', '.'), tags=('ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.')),
#  'b100-1359': Sentence(words=('Frank', 'Graham', ',', 'the', 'Journal-American', 'sports', 'columnist', ';', ';'), tags=('NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.')),
#  'b100-55806': Sentence(words=('Health', ',', 'excellent', '.'), tags=('NOUN', '.', 'ADJ', '.')),
#  'b100-26819': Sentence(words=('Serenity', ',', 'if', 'one', 'is', 'fortunate', 'enough', 'to', 'achieve', 'it', ',', 'is', 'not', 'so', 'good', 'as', 'joy', ',', 'but', 'it', 'is', 'something', '.'), tags=('NOUN', '.', 'ADP', 'NOUN', 'VERB', 'ADJ', 'ADV', 'PRT', 'VERB', 'PRON', '.', 'VERB', 'ADV', 'ADV', 'ADJ', 'ADP', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'NOUN', '.')),
#  'b100-25707': Sentence(words=('It', 'should', 'have', 'a', 'dramatic', 'form', 'with', 'pleasing', 'language', ',', 'and', 'it', 'should', 'portray', 'incidents', 'which', 'so', 'arouse', 'pity', 'and', 'fear', 'that', 'it', 'purges', 'these', 'emotions', 'in', 'the', 'audience', '.'), tags=('PRON', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'VERB', 'NOUN', 'DET', 'ADV', 'VERB', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-18527': Sentence(words=('She', 'worked', 'as', 'a', 'domestic', ',', 'first', 'in', 'Newport', 'for', 'a', 'year', ',', 'and', 'then', 'in', 'South', 'Bethlehem', ',', 'Pennsylvania', ',', 'for', 'another', 'year', '.'), tags=('PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADV', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'ADV', 'ADP', 'ADJ', 'NOUN', '.', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-37703': Sentence(words=('These', 'tests', 'are', 'not', 'accelerated', 'and', 'must', 'be', 'repeated', 'to', 'evaluate', 'dimensional', 'changes', 'after', 'repeated', 'launderings', '.'), tags=('DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'CONJ', 'VERB', 'VERB', 'VERB', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'VERB', 'NOUN', '.')),
#  'b100-4928': Sentence(words=('The', 'death', 'of', 'Mr.', 'Hammarskjold', 'removes', 'the', 'United', "Nations'", 'most', 'controversial', 'leader', '.'), tags=('DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'DET', 'VERB', 'NOUN', 'ADV', 'ADJ', 'NOUN', '.')),
#  'b100-20375': Sentence(words=('Meanwhile', ',', 'the', 'experts', 'speak', 'of', 'wars', 'triggered', 'by', '``', 'false', 'pre-emption', "''", ',', '``', 'escalation', "''", ',', '``', 'unauthorized', 'behavior', "''", 'and', 'other', 'terms', 'that', 'will', 'be', 'discussed', 'in', 'this', 'report', '.'), tags=('ADV', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'VERB', 'ADP', '.', 'ADJ', 'NOUN', '.', '.', '.', 'NOUN', '.', '.', '.', 'ADJ', 'NOUN', '.', 'CONJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-44508': Sentence(words=('The', 'King', 'Arthur', 'had', 'fifty-four', 'overnighters', ',', 'again', 'counting', 'rooms', 'rather', 'than', 'people', '.'), tags=('DET', 'NOUN', 'NOUN', 'VERB', 'NUM', 'NOUN', '.', 'ADV', 'VERB', 'NOUN', 'ADP', 'ADP', 'NOUN', '.')),
#  'b100-12890': Sentence(words=('Inside', 'of', 'pieces', 'was', 'glazed', 'with', 'three', 'coats', 'of', 'Creek-Turn', 'bottle', 'green', 'antique', 'glaze', '.'), tags=('NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'NOUN', '.')),
#  'b100-16325': Sentence(words=('But', 'it', 'is', 'our', 'health', '--', 'more', 'precious', 'than', 'all', 'the', 'money', 'in', 'the', 'world', '--', 'that', 'these', 'modern', 'witch', 'doctors', 'with', 'their', 'fake', 'therapeutic', 'gadgets', 'are', 'gambling', 'away', '.'), tags=('CONJ', 'PRON', 'VERB', 'DET', 'NOUN', '.', 'ADV', 'ADJ', 'ADP', 'PRT', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADV', '.')),
#  'b100-5774': Sentence(words=('Over', '4', 'million', 'shares', 'were', 'sold', ',', 'the', 'highest', 'figures', 'since', 'early', 'June', '.'), tags=('PRT', 'NUM', 'NUM', 'NOUN', 'VERB', 'VERB', '.', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')),
#  'b100-5343': Sentence(words=('He', 'did', 'say', 'she', 'could', 'get', 'her', 'beef', 'and', 'vegetables', 'in', 'cans', 'this', 'summer', '.'), tags=('PRON', 'VERB', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', '.')),
#  'b100-236': Sentence(words=('Washington', ',', 'Feb.', '9'), tags=('NOUN', '.', 'NOUN', 'NUM')),
#  'b100-14903': Sentence(words=('The', 'supplier', 'delivers', 'at', 'his', 'convenience', 'in', 'transport', 'loads', ',', 'so', 'as', 'to', 'maintain', 'two-to-three', 'weeks', 'reserve', 'supply', 'against', 'weather', 'contingencies', '.'), tags=('DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'ADP', 'ADP', 'PRT', 'VERB', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.')),
#  'b100-53957': Sentence(words=('On', 'her', 'way', 'to', 'the', 'airport', ',', 'on', 'her', 'way', 'to', 'Paris', '--', 'you', 'bet', ',', 'Lucy', 'said', 'to', 'herself', '.'), tags=('ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'PRON', 'VERB', '.', 'NOUN', 'VERB', 'ADP', 'PRON', '.')),
#  'b100-3145': Sentence(words=('But', 'when', 'Gloriana', 'rides', 'with', 'them', 'they', 'also', 'have', 'to', 'take', 'the', 'two', 'girls', 'who', 'usually', 'ride', 'with', 'her', ',', 'so', 'the', 'little', 'car', "isn't", 'big', 'enough', '.'), tags=('CONJ', 'ADV', 'NOUN', 'VERB', 'ADP', 'PRON', 'PRON', 'ADV', 'VERB', 'PRT', 'VERB', 'DET', 'NUM', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADP', 'PRON', '.', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADJ', 'ADV', '.')),
#  'b100-15585': Sentence(words=('The', 'carrots', 'sometimes', "don't", 'make', 'it', 'through', 'the', 'winter', ';', ';'), tags=('DET', 'NOUN', 'ADV', 'VERB', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', '.', '.')),
#  'b100-17636': Sentence(words=('Fearful', 'of', 'inviting', 'a', 'military', 'showdown', 'with', 'the', 'West', 'which', 'they', 'could', 'not', 'win', ',', 'the', 'Communists', 'seek', 'to', 'undermine', 'Western', 'power', 'where', 'the', 'nuclear', 'might', 'of', 'the', 'West', 'is', 'irrelevant', '--', 'in', 'backwoods', 'guerrilla', 'skirmishes', ',', 'in', 'mob', 'uprisings', 'in', 'the', 'streets', ',', 'in', 'parliaments', ',', 'in', 'clandestine', 'meetings', 'of', 'undercover', 'conspirators', ',', 'at', 'the', 'United', 'Nations', ',', 'on', 'the', 'propaganda', 'front', ',', 'at', 'diplomatic', 'conferences', '--', 'preferably', 'at', 'the', 'highest', 'level', '.'), tags=('ADJ', 'ADP', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'DET', 'PRON', 'VERB', 'ADV', 'VERB', '.', 'DET', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADV', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', '.', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'ADP', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-10988': Sentence(words=('Today', 'more', 'than', 'a', 'thousand', 'industries', 'distribute', 'me', 'to', 'their', 'employees', '.'), tags=('NOUN', 'ADJ', 'ADP', 'DET', 'NUM', 'NOUN', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-29392': Sentence(words=('The', 'loss', 'in', 'growth', 'of', 'sawtimber', 'because', 'of', 'damage', 'by', 'destructive', 'agencies', 'in', 'the', 'United', 'States', 'in', '1952', 'was', 'estimated', 'to', 'be', 'about', '44', 'billion', 'board', 'feet', '.'), tags=('DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'NUM', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'NUM', 'NUM', 'NOUN', 'NOUN', '.')),
#  'b100-45869': Sentence(words=('Pretty', 'girls', 'among', 'them', ',', 'with', 'blonde', 'hair', 'and', 'pert', 'faces', '.'), tags=('ADJ', 'NOUN', 'ADP', 'PRON', '.', 'ADP', 'ADJ', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.')),
#  'b100-36847': Sentence(words=('Their', 'study', 'showed', 'that', 'it', 'was', 'possible', 'to', 'transfer', '3', 'to', '4', 'lb', 'of', 'oxygen', '/', 'hr.', '/', 'hp.'), tags=('DET', 'NOUN', 'VERB', 'ADP', 'PRON', 'VERB', 'ADJ', 'PRT', 'VERB', 'NUM', 'ADP', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN')),
#  'b100-46069': Sentence(words=('Haney', 'scowled', '.'), tags=('NOUN', 'VERB', '.')),
#  'b100-32700': Sentence(words=('As', 'seen', 'in', 'the', 'B.', 'family', ',', 'there', 'must', 'be', 'an', 'attempt', 'to', 'help', 'the', 'client', 'develop', 'conscious', 'awareness', 'of', 'the', 'problem', ',', 'especially', 'in', 'the', 'absence', 'of', 'a', 'formal', 'request', 'for', 'assistance', '.'), tags=('ADP', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'PRT', 'VERB', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-45734': Sentence(words=('He', 'crawled', 'into', 'bed', 'and', 'switched', 'off', 'the', 'light', '.'), tags=('PRON', 'VERB', 'ADP', 'NOUN', 'CONJ', 'VERB', 'PRT', 'DET', 'NOUN', '.')),
#  'b100-595': Sentence(words=('But', 'Mr.', 'Buckley', 'seems', 'to', 'have', 'assumed', 'he', 'would', 'be', 'given', 'the', 'right', 'to', 'pick', 'Mr.', "Gerosa's", 'successor', '.'), tags=('CONJ', 'NOUN', 'NOUN', 'VERB', 'PRT', 'VERB', 'VERB', 'PRON', 'VERB', 'VERB', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NOUN', 'NOUN', 'NOUN', '.')),
#  'b100-25478': Sentence(words=('This', ',', 'manifestly', ',', 'would', 'not', 'provide', '$5000', 'to', 'each', 'of', 'the', 'surviving', 'five', 'children', '.'), tags=('DET', '.', 'ADV', '.', 'VERB', 'ADV', 'VERB', 'NOUN', 'ADP', 'DET', 'ADP', 'DET', 'VERB', 'NUM', 'NOUN', '.')),
#  'b100-3114': Sentence(words=('What', 'most', 'people', "don't", 'seem', 'to', 'realize', ',', 'if', 'they', "aren't", 'tied', 'up', 'with', 'the', 'thing', 'as', 'I', 'am', ',', 'is', 'that', '90%', 'of', 'the', 'problem', 'is', 'transportation', '.'), tags=('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', '.', 'ADP', 'PRON', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', '.', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', '.')),
#  'b100-19998': Sentence(words=('I', 'know', 'now', 'why', 'our', 'Japanese', 'friends', 'were', 'surprised', 'when', 'they', 'walked', 'into', 'our', 'bathroom', '.'), tags=('PRON', 'VERB', 'ADV', 'ADV', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADV', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-45747': Sentence(words=('He', 'let', 'his', 'eyelids', 'droop', 'and', 'breathed', 'heavily', ',', 'feigning', 'sleep', '.'), tags=('PRON', 'VERB', 'DET', 'NOUN', 'VERB', 'CONJ', 'VERB', 'ADV', '.', 'VERB', 'NOUN', '.')),
#  'b100-17332': Sentence(words=('But', 'in', 'the', 'meantime', 'the', 'beer-runner', ',', 'unhappy', 'with', 'this', 'solution', ',', 'telephoned', 'Torrio', 'and', 'returned', 'to', "O'Banion", 'with', 'the', 'message', ':', '``', 'Say', ',', 'Dionie', ',', 'I', 'just', 'been', 'talking', 'to', 'Johnny', ',', 'and', 'he', 'said', 'to', 'let', 'them', 'cops', 'have', 'the', 'three', 'hundred', '.'), tags=('CONJ', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', '.', 'ADJ', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'NOUN', 'CONJ', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'PRT', '.', 'NOUN', '.', 'PRON', 'ADV', 'VERB', 'VERB', 'ADP', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'PRT', 'VERB', 'PRON', 'NOUN', 'VERB', 'DET', 'NUM', 'NUM', '.')),
#  'b100-40013': Sentence(words=('``', 'I', 'hit', 'him', 'in', 'the', 'ass', 'once', "''", '.'), tags=('.', 'PRON', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', 'ADV', '.', '.')),
#  'b100-32501': Sentence(words=('but', 'this', 'obligation', 'pertains', 'only', 'to', 'countries', 'which', 'are', 'honestly', 'seeking', 'to', 'become', 'responsible', 'members', 'of', 'a', 'stable', 'and', 'forward-moving', 'world', 'community', '.'), tags=('CONJ', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'DET', 'VERB', 'ADV', 'VERB', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'NOUN', '.')),
#  'b100-55196': Sentence(words=('``', "I've", 'got', 'this', 'cold', '.'), tags=('.', 'PRT', 'VERB', 'DET', 'NOUN', '.')),
#  'b100-14889': Sentence(words=("There's", 'an', 'advantage', 'in', 'having', 'a', 'firm', 'like', 'Tri-State', 'headed', 'by', 'a', 'lawyer', '.'), tags=('PRT', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'VERB', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-40585': Sentence(words=('Day', 'by', 'day', ',', 'week', 'by', 'week', ',', 'month', 'by', 'month', ',', 'the', 'betrayal', 'gnawed', 'at', "Andrei's", 'heart', '.'), tags=('NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'NOUN', '.')),
#  'b100-34588': Sentence(words=('A', '.'), tags=('NOUN', '.')),
#  'b100-27617': Sentence(words=('(', 'B', ')', 'the', 'need', 'to', 'plan', 'investment', 'programs', '.'), tags=('.', 'NOUN', '.', 'DET', 'NOUN', 'PRT', 'VERB', 'NOUN', 'NOUN', '.')),
#  'b100-42872': Sentence(words=('His', 'small', ',', 'mean', 'eyes', 'regarded', 'Marty', 'steadily', ',', 'unblinkingly', '.'), tags=('DET', 'ADJ', '.', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADV', '.', 'ADV', '.')),
#  'b100-8550': Sentence(words=('Just', 'the', 'evocations', 'of', 'time', 'and', 'place', ',', 'of', 'passionate', 'encounter', 'between', 'man', 'and', 'a', 'natural', 'world', 'which', 'today', 'seems', 'almost', 'lost', ',', 'would', 'be', 'enough', '.'), tags=('ADV', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', '.', 'VERB', 'VERB', 'ADJ', '.')),
#  'b100-2674': Sentence(words=('Both', 'of', 'those', 'have', 'had', 'dynamic', 'run-ups', 'in', 'price', 'on', 'the', 'market', 'in', 'recent', 'months', ',', 'both', 'were', 'selling', 'at', 'higher', 'price-earnings', 'and', 'yield', 'bases', 'than', 'Morton', 'was', 'coming', 'to', 'market', 'at', ',', 'and', 'everyone', 'who', 'knew', 'anything', 'about', 'it', 'expected', 'the', 'Morton', 'stock', 'to', 'have', 'a', 'fast', 'run-up', '.'), tags=('DET', 'ADP', 'DET', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'DET', 'VERB', 'VERB', 'ADP', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', '.', 'CONJ', 'NOUN', 'PRON', 'VERB', 'NOUN', 'ADP', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-16508': Sentence(words=('Dr.', 'Karlis', 'Osis', ',', 'Director', 'of', 'Research', 'at', 'the', 'Parapsychology', 'Foundation', ',', 'described', 'the', 'basis', 'for', 'the', 'experiment', 'in', 'a', 'tomorrow', 'article', ',', '(', '``', 'New', 'Research', 'On', 'Survival', 'After', 'Death', "''", ',', 'Spring', '1958', ')', '.'), tags=('NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', '.', '.', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NUM', '.', '.')),
#  'b100-47891': Sentence(words=('What', 'else', 'he', 'said', 'was', 'lost', 'in', 'the', 'rattle', 'of', 'gunfire', 'on', 'all', 'sides', '.'), tags=('DET', 'ADV', 'PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'PRT', 'NOUN', '.')),
#  'b100-38012': Sentence(words=('The', 'discussion', 'of', 'the', 'optimal', 'policy', 'when', 'the', 'outcome', 'of', 'one', 'stage', 'is', 'not', 'known', 'before', 'passing', 'to', 'the', 'next', 'is', 'a', 'very', 'much', 'more', 'difficult', 'matter', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADV', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADP', 'VERB', 'ADP', 'DET', 'ADJ', 'VERB', 'DET', 'ADV', 'ADV', 'ADV', 'ADJ', 'NOUN', '.')),
#  'b100-15616': Sentence(words=('At', 'the', 'beginning', 'of', 'the', 'school', 'year', ',', 'the', 'new', 'students', "don't", 'eat', 'the', 'cereal', 'right', 'away', ',', 'but', 'within', 'a', 'short', 'time', 'they', 'are', 'eating', 'it', 'voraciously', '.'), tags=('ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'ADV', 'ADV', '.', 'CONJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRON', 'ADV', '.')),
#  'b100-12622': Sentence(words=('A', 'picnic', 'bag', ',', 'a', 'grill', ',', 'a', 'cooler', 'for', 'soft', 'drinks', 'and', 'beer', ',', 'and', 'for', 'frozen', 'convenience', 'foods', '.'), tags=('DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'CONJ', 'NOUN', '.', 'CONJ', 'ADP', 'VERB', 'NOUN', 'NOUN', '.')),
#  'b100-30133': Sentence(words=('A', 'Sunday', 'evening', 'program', 'provides', 'theological', 'lectures', ',', 'music', ',', 'drama', ',', 'and', 'films', 'related', 'to', 'the', 'issues', 'of', 'the', 'Judeo-Christian', 'tradition', '.'), tags=('DET', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-44785': Sentence(words=('Arthur', "Williams's", 'might', 'well', 'have', 'been', 'included', ',', 'he', 'felt', '.'), tags=('NOUN', 'NOUN', 'VERB', 'ADV', 'VERB', 'VERB', 'VERB', '.', 'PRON', 'VERB', '.')),
#  'b100-3822': Sentence(words=('They', 'had', 'the', 'unspoken', 'support', 'of', 'President-elect', 'Kennedy', ',', 'whose', 'own', 'legislative', 'program', 'was', 'menaced', 'by', 'the', 'Rules', 'Committee', 'bottleneck', '.'), tags=('PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.')),
#  'b100-28032': Sentence(words=('It', 'is', 'not', 'within', 'the', 'scope', 'of', 'this', 'report', 'to', 'elaborate', 'in', 'any', 'great', 'detail', 'upon', 'special', 'districts', 'in', 'Rhode', 'Island', '.'), tags=('PRON', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.')),
#  'b100-30898': Sentence(words=('To', 'prepare', 'the', 'latter', ',', 'silver', 'chloride', 'was', 'precipitated', 'from', 'a', 'solution', 'containing', 'Af', 'obtained', 'from', 'the', 'Oak', 'Ridge', 'National', 'Laboratory', '.'), tags=('PRT', 'VERB', 'DET', 'ADJ', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADJ', 'NOUN', '.')),
#  'b100-996': Sentence(words=('Church', 'loses', 'pace'), tags=('NOUN', 'VERB', 'NOUN')),
#  'b100-4499': Sentence(words=('At', 'the', 'same', 'time', ',', 'another', 'purpose', 'of', 'the', 'conference', 'will', 'be', 'to', 'get', 'certain', 'low-wage', 'countries', 'to', 'control', 'textile', 'exports', '--', 'especially', 'dumping', 'of', 'specific', 'products', '--', 'to', 'high-wage', 'textile-producing', 'countries', '.'), tags=('ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'PRT', 'VERB', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'ADP', 'NOUN', 'ADJ', 'NOUN', '.')),
#  'b100-23554': Sentence(words=('Because', 'of', 'its', 'wealth', 'of', 'experience', ',', 'the', 'Organization', 'for', 'European', 'Economic', 'Cooperation', 'could', 'help', 'with', 'the', 'initial', 'studies', 'needed', '.'), tags=('ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', '.')),
#  'b100-22053': Sentence(words=('On', 'the', 'face', 'of', 'it', ',', 'it', 'is', 'because', 'he', 'employs', 'deductive', 'techniques', 'alien', 'to', 'official', 'police', 'routine', '.'), tags=('ADP', 'DET', 'NOUN', 'ADP', 'PRON', '.', 'PRON', 'VERB', 'ADP', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADJ', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.')),
#  'b100-28285': Sentence(words=('The', 'fullest', 'cooperation', 'by', 'and', 'with', 'Atomic', 'Energy', 'Commission', ',', 'the', 'Department', 'of', 'Health', ',', 'Education', ',', 'and', 'Welfare', ',', 'the', 'Department', 'of', 'State', ',', 'and', 'other', 'concerned', 'agencies', 'shall', 'also', 'be', 'carried', 'out', 'in', 'the', 'interest', 'of', 'achieving', 'the', 'objectives', 'of', 'this', 'Act', '.'), tags=('DET', 'ADJ', 'NOUN', 'ADP', 'CONJ', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'CONJ', 'ADJ', 'VERB', 'NOUN', 'VERB', 'ADV', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-52053': Sentence(words=('and', 'now', 'the', 'East', 'was', 'creating', 'government', 'agencies', 'for', 'which', 'the', 'West', 'doubtless', 'would', 'have', 'to', 'pay', '.'), tags=('CONJ', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'DET', 'NOUN', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', '.')),
#  'b100-52432': Sentence(words=('Four', 'little', 'Japanese', 'waitresses', 'were', 'murdering', 'the', 'English', 'language', 'at', 'the', 'counter', '--', 'Yuki', 'Kobayashi', 'happened', 'to', 'be', 'one', 'of', 'them', '.'), tags=('NUM', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'PRT', 'VERB', 'NOUN', 'ADP', 'PRON', '.')),
#  'b100-56489': Sentence(words=("''", 'I', 'thought', ',', 'and', 'wondered', 'what', 'kind', 'of', 'homesteads', 'such', 'odd', 'pioneers', 'would', 'establish', 'in', 'this', 'suburban', 'frontier', ';', ';'), tags=('.', 'PRON', 'VERB', '.', 'CONJ', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.', '.')),
#  'b100-33720': Sentence(words=('Swadesh', 'in', 'short', 'was', 'trying', 'to', 'develop', 'a', 'basic', 'list', 'that', 'was', 'universal', ';', ';'), tags=('NOUN', 'ADP', 'ADJ', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'ADJ', '.', '.')),
#  'b100-16464': Sentence(words=('This', 'knowledge', 'both', 'modifies', 'and', 'dictates', 'diagnosis', 'and', 'treatment', '.'), tags=('DET', 'NOUN', 'DET', 'VERB', 'CONJ', 'VERB', 'NOUN', 'CONJ', 'NOUN', '.')),
#  'b100-18361': Sentence(words=('Forty', 'miles', 'farther', 'north', 'is', 'Mount', 'Moosilauke', ',', "Dartmouth's", 'own', 'mountain', '.'), tags=('NUM', 'NOUN', 'ADV', 'NOUN', 'VERB', 'NOUN', 'NOUN', '.', 'NOUN', 'ADJ', 'NOUN', '.')),
#  'b100-34889': Sentence(words=('to', 'refine', 'and', 'extend', 'his', 'own', 'techniques', 'for', 'studying', 'individual', 'children', ';', ';'), tags=('PRT', 'VERB', 'CONJ', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'VERB', 'ADJ', 'NOUN', '.', '.')),
#  'b100-51083': Sentence(words=('Artie', 'had', 'picked', 'up', 'a', 'snorkle', 'and', 'was', 'twirling', 'it', 'on', 'his', 'forefinger', '.'), tags=('NOUN', 'VERB', 'VERB', 'PRT', 'DET', 'NOUN', 'CONJ', 'VERB', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-10539': Sentence(words=('It', 'is', 'this', 'atomic', 'nucleus', 'that', 'contains', 'the', 'positive', 'charge', 'of', 'electricity', 'holding', 'these', 'negatively', 'charged', 'electrons', 'in', 'their', 'orbits', ';', ';'), tags=('PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'VERB', 'DET', 'ADV', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.')),
#  'b100-2182': Sentence(words=('The', 'motorist', 'later', 'was', 'identified', 'as', 'Richard', 'Sarkees', ',', '17', ',', 'of', '2433', 'McClellan', ',', 'currently', 'on', 'probation', 'and', 'under', 'court', 'order', 'not', 'to', 'drive', '.'), tags=('DET', 'NOUN', 'ADV', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'NUM', '.', 'ADP', 'NUM', 'NOUN', '.', 'ADV', 'ADP', 'NOUN', 'CONJ', 'ADP', 'NOUN', 'NOUN', 'ADV', 'PRT', 'VERB', '.')),
#  'b100-9826': Sentence(words=('Our', 'necks', 'are', 'stiff', 'from', 'gazing', 'at', 'the', 'wonders', 'of', 'outer', 'space', ',', 'which', 'have', 'captured', 'the', 'imagination', 'of', 'the', 'American', 'public', '.'), tags=('DET', 'NOUN', 'VERB', 'ADJ', 'ADP', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'DET', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-53338': Sentence(words=('My', "name's", 'Carla', 'Caneli', '.'), tags=('DET', 'PRT', 'NOUN', 'NOUN', '.')),
#  'b100-47702': Sentence(words=('Beyond', 'the', 'stockade', 'rifles', 'began', 'to', 'explode', 'as', 'some', 'of', 'the', 'guerrillas', 'fired', 'at', 'shadows', 'that', 'they', 'imagined', 'were', 'Apaches', '.'), tags=('ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'NOUN', '.')),
#  'b100-3575': Sentence(words=('The', 'deadlock', 'has', 'been', 'caused', 'by', 'the', "Russians'", 'new', 'demand', 'for', 'a', 'three-man', '(', 'East', ',', 'West', 'and', 'neutral', ')', 'directorate', ',', 'and', 'thus', 'a', 'veto', ',', 'over', 'the', 'control', 'machinery', '.'), tags=('DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', '.', 'NOUN', '.', 'ADJ', 'CONJ', 'ADJ', '.', 'NOUN', '.', 'CONJ', 'ADV', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', '.')),
#  'b100-53690': Sentence(words=("It's", 'quite', 'a', 'big', 'one', "''", ',', 'he', 'added', '.'), tags=('PRT', 'PRT', 'DET', 'ADJ', 'NOUN', '.', '.', 'PRON', 'VERB', '.')),
#  'b100-52237': Sentence(words=('There', 'had', 'been', 'more', 'to', 'know', 'about', 'Hetty', ',', 'inevitably', ',', 'and', 'most', 'of', 'it', 'unfavorable', '.'), tags=('PRT', 'VERB', 'VERB', 'ADJ', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'ADV', '.', 'CONJ', 'ADJ', 'ADP', 'PRON', 'ADJ', '.')),
#  'b100-43437': Sentence(words=('There', 'was', 'a', 'marked', 'contrast', 'in', 'the', 'amount', 'of', 'information', 'on', 'bride', 'and', 'groom', '.'), tags=('PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.')),
#  'b100-7693': Sentence(words=('He', 'suggests', 'that', 'Gore', 'Court', 'embodies', 'all', 'the', 'glories', 'of', 'Tudor', 'splendor', '.'), tags=('PRON', 'VERB', 'ADP', 'NOUN', 'NOUN', 'VERB', 'PRT', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.')),
#  'b100-22370': Sentence(words=('These', 'proposals', 'would', 'go', 'far', 'toward', 'creating', 'the', 'economic', 'atmosphere', 'favoring', 'growth', 'of', 'the', 'individual', ',', 'who', ',', 'in', 'turn', ',', 'would', 'help', 'us', 'to', 'cope', 'with', 'runaway', 'technology', '.'), tags=('DET', 'NOUN', 'VERB', 'VERB', 'ADV', 'ADP', 'VERB', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', '.', 'ADP', 'NOUN', '.', 'VERB', 'VERB', 'PRON', 'PRT', 'VERB', 'ADP', 'ADJ', 'NOUN', '.')),
#  'b100-42295': Sentence(words=('``', 'No', '.'), tags=('.', 'ADV', '.')),
#  'b100-4131': Sentence(words=('One', 'of', 'Nikita', "Khrushchev's", 'most', 'enthusiastic', 'eulogizers', ',', 'the', "U.S.S.R.'s", 'daily', 'Izvestia', ',', 'enterprisingly', 'interviewed', 'Red-prone', 'Comedian', 'Charlie', 'Chaplin', 'at', 'his', 'Swiss', 'villa', ',', 'where', 'he', 'has', 'been', 'in', 'self-exile', 'since', '1952', '.'), tags=('NUM', 'ADP', 'NOUN', 'NOUN', 'ADV', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'NUM', '.')),
#  'b100-53482': Sentence(words=('Even', 'he', ',', 'wanting', 'her', ',', 'afraid', 'of', 'her', 'and', 'not', 'knowing', 'how', 'to', 'press', 'his', 'suit', ',', 'feared', 'the', 'evil', 'presences', 'in', 'her', 'metabolism', 'more', '.'), tags=('ADV', 'PRON', '.', 'VERB', 'PRON', '.', 'ADJ', 'ADP', 'PRON', 'CONJ', 'ADV', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADV', '.')),
#  'b100-3162': Sentence(words=('Pasadena', 'listings'), tags=('NOUN', 'NOUN')),
#  'b100-4491': Sentence(words=('The', 'recently', 'unveiled', 'Kennedy', 'moves', 'to', 'control', 'the', 'international', 'textile', 'market', 'can', 'be', 'significant', 'for', 'American', 'businessmen', 'in', 'many', 'lines', '.'), tags=('DET', 'ADV', 'VERB', 'NOUN', 'NOUN', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')),
#  'b100-48711': Sentence(words=('``', 'We', 'aim', "t'", 'be', 'see-lective', ',', "y'know", '?', '?'), tags=('.', 'PRON', 'VERB', 'PRT', 'VERB', 'ADJ', '.', 'PRT', '.', '.')),
#  'b100-46027': Sentence(words=('He', 'muttered', 'something', 'about', 'how', 'terrible', 'it', 'was', ',', 'and', 'walked', 'with', 'deliberate', 'slowness', 'to', 'the', 'elevator', '.'), tags=('PRON', 'VERB', 'NOUN', 'ADP', 'ADV', 'ADJ', 'PRON', 'VERB', '.', 'CONJ', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-44096': Sentence(words=('He', 'flew', 'about', 'the', 'place', 'making', 'these', 'adjustments', 'and', 'it', 'was', 'obvious', 'that', 'what', 'he', 'was', 'doing', 'was', 'the', 'fruit', 'of', 'long', 'experience', '.'), tags=('PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'CONJ', 'PRON', 'VERB', 'ADJ', 'ADP', 'DET', 'PRON', 'VERB', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')),
#  'b100-48630': Sentence(words=('Never', ',', "he'd", 'once', 'told', 'Joyce', ',', 'had', 'he', 'encountered', 'any', 'man', 'or', 'situation', 'that', 'called', 'for', 'a', 'gun', '.'), tags=('ADV', '.', 'PRT', 'ADV', 'VERB', 'NOUN', '.', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-33365': Sentence(words=('Then', 'I', 'replied', ',', 'coldly', ',', '``', 'If', 'you', 'despise', 'me', ',', 'why', "don't", 'you', 'say', 'so', ',', 'directly', "''", '?', '?'), tags=('ADV', 'PRON', 'VERB', '.', 'ADV', '.', '.', 'ADP', 'PRON', 'VERB', 'PRON', '.', 'ADV', 'VERB', 'PRON', 'VERB', 'ADV', '.', 'ADV', '.', '.', '.')),
#  'b100-18224': Sentence(words=('When', 'the', 'Negroes', 'landed', 'at', 'Boston', 'a', 'month', 'later', 'they', 'were', ',', 'of', 'course', ',', 'no', 'longer', 'slaves', '.'), tags=('ADV', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADV', 'PRON', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'ADV', 'NOUN', '.')),
#  'b100-46919': Sentence(words=('``', 'All', 'I', 'know', 'is', 'that', 'you', 'were', 'outside', 'the', 'bubbles', 'last', 'night', ',', 'and', 'you', 'were', 'the', 'only', 'sentient', 'being', 'who', 'came', 'in', 'or', 'out', 'of', 'our', 'alarm', 'web', '.'), tags=('.', 'PRT', 'PRON', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'PRT', 'CONJ', 'PRT', 'ADP', 'DET', 'NOUN', 'NOUN', '.')),
#  'b100-7148': Sentence(words=('The', 'planners', 'in', 'Taiwan', 'struck', 'me', 'as', 'realistic', 'men', '.'), tags=('DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'PRON', 'ADP', 'ADJ', 'NOUN', '.')),
#  'b100-4395': Sentence(words=('Most', 'members', 'of', 'the', 'U.S.', 'Senate', ',', 'because', 'they', 'are', 'human', ',', 'like', 'to', 'eat', 'as', 'high', 'on', 'the', 'hog', 'as', 'they', 'can', '.'), tags=('ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'ADJ', '.', 'VERB', 'PRT', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', '.')),
#  'b100-5082': Sentence(words=('The', 'Jackson', 'report', 'will', 'provide', 'some', 'of', 'the', 'political', 'support', 'Mr.', 'Rusk', 'will', 'need', 'if', 'he', 'is', 'to', 'get', 'rid', 'of', 'department', 'personnel', 'engaged', ',', 'as', 'Sen.', 'Jackson', 'puts', 'it', ',', '``', 'in', 'work', 'that', 'does', 'not', 'really', 'need', 'doing', "''", '.'), tags=('DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'DET', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'ADJ', 'ADP', 'NOUN', 'NOUN', 'VERB', '.', 'ADP', 'NOUN', 'NOUN', 'VERB', 'PRON', '.', '.', 'ADP', 'NOUN', 'PRON', 'VERB', 'ADV', 'ADV', 'VERB', 'VERB', '.', '.')),
#  'b100-8868': Sentence(words=('Expands', 'and', 'contracts'), tags=('VERB', 'CONJ', 'VERB')),
#  'b100-22273': Sentence(words=('The', 'second', 'specific', 'comment', 'was', 'the', 'report', 'of', "Eisenhower's", 'Commission', 'on', 'National', 'Goals', ',', 'titled', 'Goals', 'For', 'Americans', '.'), tags=('DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'VERB', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-25697': Sentence(words=('for', 'if', 'this', 'can', 'be', 'proved', 'we', 'shall', 'surely', 'be', 'the', 'gainers', '--', 'I', 'mean', ',', 'if', 'there', 'is', 'a', 'use', 'in', 'poetry', 'as', 'well', 'as', 'a', 'delight', "''", '.'), tags=('ADP', 'ADP', 'DET', 'VERB', 'VERB', 'VERB', 'PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', '.', 'PRON', 'VERB', '.', 'ADP', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', '.', '.')),
#  'b100-1428': Sentence(words=('He', 'had', 'a', '16', '.'), tags=('PRON', 'VERB', 'DET', 'NUM', '.')),
#  'b100-51477': Sentence(words=('He', 'said', ',', 'lapsing', 'into', 'the', 'profanity', 'he', 'often', 'used', 'when', 'away', 'from', 'his', 'parents', 'and', 'especially', 'when', 'he', 'was', 'with', 'Charles', '.'), tags=('PRON', 'VERB', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'CONJ', 'ADV', 'ADV', 'PRON', 'VERB', 'ADP', 'NOUN', '.')),
#  'b100-56706': Sentence(words=('He', 'followed', 'Mr.', 'Blatz', 'up', 'the', 'cellar', 'stairs', '.'), tags=('PRON', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.')),
#  'b100-4215': Sentence(words=('The', 'Belgians', 'were', 'interested', 'primarily', 'in', 'the', 'economic', 'development', 'of', 'the', 'Congo', ',', 'which', 'is', 'rich', 'in', 'copper', ',', 'tin', ',', 'cobalt', ',', 'manganese', ',', 'zinc', ',', 'and', 'uranium', ',', 'and', 'cotton', 'and', 'palm', 'oil', '.'), tags=('DET', 'NOUN', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'VERB', 'ADJ', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'NOUN', '.', 'CONJ', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.')),
#  'b100-37086': Sentence(words=('Two', 'metabolites', '(', '1', ',', 'and', '2', ')', ')', 'of', 'p-aminobenzoic', 'acid', '(', 'PABA', ')', 'which', 'act', 'as', 'cofactors', 'for', 'the', 'hydroxylation', 'of', 'aniline', 'by', 'acid-fast', 'bacteria', 'are', 'biosynthesized', 'from', 'Aj', '.'), tags=('NUM', 'NOUN', '.', 'NUM', '.', 'CONJ', 'NUM', '.', '.', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'DET', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', '.')),
#  'b100-36897': Sentence(words=('Ice', 'caused', 'the', 'aerator', 'to', 'overload', ',', 'straining', 'the', 'drive', 'belts', '.'), tags=('NOUN', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', '.', 'VERB', 'DET', 'NOUN', 'NOUN', '.')),
#  'b100-56915': Sentence(words=('There', 'was', 'a', 'long', 'silence', '.'), tags=('PRT', 'VERB', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-6358': Sentence(words=('I', 'regret', 'that', 'Bertha', 'Madeira', '(', "Today's", '``', 'Voice', "''", ')', 'obtained', 'incorrect', 'information', '.'), tags=('PRON', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', '.', 'VERB', 'ADJ', 'NOUN', '.')),
#  'b100-36242': Sentence(words=("Fromm's", 'analysis', 'of', 'alienation', 'in', 'the', 'sphere', 'of', 'production', 'centers', 'around', 'the', 'concepts', 'of', 'the', 'bureaucratization', 'of', 'the', 'corporation', ',', 'the', 'separation', 'of', 'ownership', 'from', 'control', ',', 'and', 'the', 'broad', '(', 'and', 'thus', 'from', 'the', 'point', 'of', 'view', 'of', 'corporate', 'control', ',', 'ineffective', ')', 'dispersion', 'of', 'stock', 'ownership', '.'), tags=('NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'CONJ', 'DET', 'ADJ', '.', 'CONJ', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'ADJ', '.', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.')),
#  'b100-26222': Sentence(words=('When', 'the', 'United', 'States', 'entered', 'the', 'First', 'World', 'War', 'Baker', 'made', 'certain', 'that', 'the', 'Draft', 'Act', 'of', '1917', 'prohibited', 'the', 'sale', 'of', 'liquor', 'to', 'men', 'in', 'uniform', 'and', 'that', 'it', 'provided', 'for', 'broad', 'zones', 'around', 'the', 'camps', 'in', 'which', 'prostitution', 'was', 'outlawed', '.'), tags=('ADV', 'DET', 'VERB', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NUM', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'ADP', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', '.')),
#  'b100-15299': Sentence(words=('This', ',', 'for', 'obvious', 'reasons', ',', 'makes', 'their', 'techniques', 'superbly', 'useful', 'in', 'studying', 'the', 'psychiatric', 'interview', ',', 'so', 'useful', ',', 'in', 'fact', ',', 'that', 'they', 'have', 'been', 'successfully', 'used', 'to', 'suggest', 'ways', 'to', 'speed', 'diagnosis', 'and', 'to', 'evaluate', 'the', 'progress', 'of', 'therapy', '.'), tags=('DET', '.', 'ADP', 'ADJ', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'ADV', 'ADJ', 'ADP', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'ADJ', '.', 'ADP', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'VERB', 'ADV', 'VERB', 'PRT', 'VERB', 'NOUN', 'PRT', 'VERB', 'NOUN', 'CONJ', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-6455': Sentence(words=('The', 'bill', 'which', 'passed', 'the', 'Assembly', 'last', 'May', 'and', 'is', 'now', 'pending', 'in', 'the', 'Senate', 'should', 'be', 'given', 'careful', 'scrutiny', '.'), tags=('DET', 'NOUN', 'DET', 'VERB', 'DET', 'NOUN', 'ADJ', 'NOUN', 'CONJ', 'VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADJ', 'NOUN', '.')),
#  'b100-47049': Sentence(words=('``', 'Are', 'you', 'my', 'partner', "''", '?', '?'), tags=('.', 'VERB', 'PRON', 'DET', 'NOUN', '.', '.', '.')),
#  'b100-22176': Sentence(words=('The', 'connective', 'system', ',', 'or', 'network', ',', 'is', 'tailored', 'to', 'meet', 'the', 'requirements', 'of', 'the', 'objective', ',', 'and', 'it', 'is', 'therefore', 'not', 'surprising', 'that', 'a', 'military', 'body', 'acting', 'as', 'a', 'single', 'coordinated', 'unit', 'has', 'a', 'different', 'communication', 'network', 'than', 'a', 'factory', ',', 'a', 'college', ',', 'or', 'a', 'rural', 'village', '.'), tags=('DET', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', '.', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'ADV', 'ADV', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'VERB', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', '.', 'CONJ', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-43516': Sentence(words=('And', 'Mr.', 'Skyros', "didn't", 'like', 'Angie', ',', 'but', 'what', 'with', 'Prettyman', 'and', 'three', 'of', 'his', 'boys', 'inside', ',', 'and', 'not', 'likely', 'to', 'come', 'out', '--', 'And', 'Angie', 'such', 'a', 'valuable', 'salesman', ',', 'Prettyman', 'said', '--', 'All', 'the', 'nuisance', 'and', 'danger', 'of', 'getting', 'in', 'touch', 'with', 'practically', 'a', 'whole', 'new', 'bunch', 'of', 'boys', '--', 'Why', 'did', 'everything', 'have', 'to', 'happen', 'at', 'once', '?', '?'), tags=('CONJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'NOUN', '.', 'CONJ', 'DET', 'ADP', 'NOUN', 'CONJ', 'NUM', 'ADP', 'DET', 'NOUN', 'ADV', '.', 'CONJ', 'ADV', 'ADV', 'PRT', 'VERB', 'PRT', '.', 'CONJ', 'NOUN', 'PRT', 'DET', 'ADJ', 'NOUN', '.', 'NOUN', 'VERB', '.', 'ADV', 'DET', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADV', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADV', 'VERB', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'ADV', '.', '.')),
#  'b100-48270': Sentence(words=('What', 'sort', 'of', 'men', 'I', 'would', 'come', 'into', 'contact', 'with', ',', 'at', 'the', 'hall', '?', '?'), tags=('DET', 'NOUN', 'ADP', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', '.', 'ADP', 'DET', 'NOUN', '.', '.')),
#  'b100-13693': Sentence(words=('It', 'must', 'be', 'conceded', 'that', 'his', 'native', 'land', 'provided', 'Prokofieff', 'with', 'many', 'of', 'the', 'necessary', 'conditions', 'for', 'great', 'creative', 'incentive', ':', 'economic', 'security', 'and', 'cultural', 'opportunities', ',', 'incisive', 'idioms', ',', 'social', 'fermentations', 'for', 'a', 'new', 'national', 'ideology', '--', 'a', 'sympathetic', 'public', 'and', 'a', 'large', 'body', 'of', 'performers', 'especially', 'trained', 'to', 'fulfill', 'his', 'purpose', '.'), tags=('PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', '.', 'ADJ', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.', 'ADJ', 'NOUN', '.', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', '.', 'DET', 'ADJ', 'ADJ', 'CONJ', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADV', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', '.')),
#  'b100-13685': Sentence(words=('time', 'and', 'economic', 'security', ';', ';'), tags=('NOUN', 'CONJ', 'ADJ', 'NOUN', '.', '.')),
#  'b100-37627': Sentence(words=('In', 'the', 'prepolymer', 'system', ',', 'the', 'isocyanate', 'and', 'resin', 'are', 'mixed', 'anhydrously', 'and', 'no', 'foaming', 'occurs', '.'), tags=('ADP', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADV', 'CONJ', 'DET', 'NOUN', 'VERB', '.')),
#  'b100-39550': Sentence(words=('While', 'this', 'was', 'being', 'discussed', ',', 'we', 'saw', 'the', 'militia', 'to', 'the', 'west', 'of', 'us', 'fanning', 'out', 'and', 'breaking', 'into', 'little', 'clusters', 'of', 'two', 'and', 'three', 'men', 'as', 'they', 'approached', 'the', 'road', '.'), tags=('ADP', 'DET', 'VERB', 'VERB', 'VERB', '.', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'CONJ', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'NUM', 'NOUN', 'ADP', 'PRON', 'VERB', 'DET', 'NOUN', '.')),
#  'b100-46524': Sentence(words=('Hal', 'knew', 'that', 'when', 'that', 'side', 'of', 'Earth', 'rotated', 'into', 'the', 'night', 'zone', ',', 'Sigmen', 'City', 'would', 'blaze', 'out', 'into', 'space', '.'), tags=('NOUN', 'VERB', 'ADP', 'ADV', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADP', 'NOUN', '.')),
#  'b100-39898': Sentence(words=('He', 'seemed', 'to', 'be', 'muttering', ',', 'his', 'voice', 'surprisingly', 'clear', '.'), tags=('PRON', 'VERB', 'PRT', 'VERB', 'VERB', '.', 'DET', 'NOUN', 'ADV', 'ADJ', '.')),
#  'b100-21306': Sentence(words=('It', 'is', 'not', 'a', 'mess', 'you', 'can', 'make', 'sense', 'of', "''", '.'), tags=('PRON', 'VERB', 'ADV', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'NOUN', 'ADP', '.', '.')),
#  'b100-24622': Sentence(words=('Yet', 'his', 'editors', 'did', 'not', 'abandon', 'their', 'sense', 'of', 'story', 'value', '.'), tags=('CONJ', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.')),
# ...
#  'b100-28026': Sentence(words=('The', 'urban', 'land', 'use', 'study', 'carried', 'out', 'by', 'the', 'planning', 'division', 'staff', 'has', 'consisted', 'of', 'identifying', 'and', 'mapping', 'all', 'urban', 'land', 'uses', 'which', 'are', 'of', 'significance', 'to', 'statewide', 'planning', '.'), tags=('DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'PRT', 'ADP', 'DET', 'VERB', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'VERB', 'CONJ', 'VERB', 'PRT', 'ADJ', 'NOUN', 'NOUN', 'DET', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')),
#  'b100-17232': Sentence(words=('Dominated', 'by', 'the', 'vicious', 'circle', 'of', 'the', 'university', 'promotion', 'system', ',', 'the', 'analyst', 'looks', 'down', 'on', 'and', 'gets', 'along', 'poorly', 'with', 'the', 'other', 'three', 'groups', ',', 'although', 'he', 'cannot', 'deny', 'his', 'debt', 'to', 'the', 'collector', '.'), tags=('VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'PRT', 'ADP', 'CONJ', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'ADJ', 'NUM', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-38241': Sentence(words=('He', 'said', 'fussily', ',', '``', 'Just', 'keep', 'the', 'cap', 'on', 'those', 'strong', 'emotions', "''", '.'), tags=('PRON', 'VERB', 'ADV', '.', '.', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', '.')),
#  'b100-39391': Sentence(words=('Still', ',', 'just', 'for', 'the', 'ladies', ',', 'and', 'just', 'for', 'this', 'once', ',', 'for', 'this', 'one', 'weekend', 'in', 'the', 'country', ',', 'he', 'would', 'make', 'a', 'little', 'piece', 'out', 'of', 'his', 'melodies', '.'), tags=('ADV', '.', 'ADV', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'ADV', 'ADP', 'DET', 'ADV', '.', 'ADP', 'DET', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRT', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-38422': Sentence(words=('He', 'and', 'Warren', 'had', 'traveled', 'together', 'for', 'four', 'days', '.'), tags=('PRON', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADV', 'ADP', 'NUM', 'NOUN', '.')),
#  'b100-56403': Sentence(words=("Here's", 'a', 'household', 'hint', ':', 'if', 'you', "can't", 'find', 'your', 'children', ',', 'and', 'get', 'tired', 'of', 'calling', 'them', ',', 'pick', 'up', 'the', 'phone', '.'), tags=('PRT', 'DET', 'NOUN', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'VERB', 'DET', 'NOUN', '.', 'CONJ', 'VERB', 'VERB', 'ADP', 'VERB', 'PRON', '.', 'VERB', 'PRT', 'DET', 'NOUN', '.')),
#  'b100-28016': Sentence(words=('The', 'work', 'program', ',', 'as', 'it', 'was', 'originally', 'proposed', ',', 'was', 'to', 'take', 'five', 'years', 'to', 'complete', '.'), tags=('DET', 'NOUN', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'ADV', 'VERB', '.', 'VERB', 'PRT', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', '.')),
#  'b100-48745': Sentence(words=('But', 'he', "couldn't", 'keep', 'up', 'with', 'them', '.'), tags=('CONJ', 'PRON', 'VERB', 'VERB', 'PRT', 'ADP', 'PRON', '.')),
#  'b100-36886': Sentence(words=('The', 'data', 'indicated', 'that', 'the', 'organic', 'load', 'during', 'the', '6-hr.', 'composites', 'was', 'essentially', '50', 'per', 'cent', 'of', 'the', '24-hr.', 'organic', 'load', '.'), tags=('DET', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADV', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', '.')),
#  'b100-14255': Sentence(words=('Prevents', 'and', 'treats', 'acetonemia', '(', 'ketosis', ')', 'in', 'dairy', 'cows', '.'), tags=('VERB', 'CONJ', 'VERB', 'NOUN', '.', 'NOUN', '.', 'ADP', 'NOUN', 'NOUN', '.')),
#  'b100-4990': Sentence(words=('Better', 'ask', 'before', 'joining'), tags=('ADJ', 'VERB', 'ADP', 'VERB')),
#  'b100-3443': Sentence(words=('It', 'is', 'the', "AID's", 'intention', 'to', 'create', 'in', 'the', 'library', '``', 'a', 'miniature', 'museum', 'of', 'Americana', "''", 'before', 'completed', 'refurbishing', 'is', 'unveiled', 'early', 'this', 'fall', '.'), tags=('PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'VERB', 'NOUN', 'VERB', 'VERB', 'ADV', 'DET', 'NOUN', '.')),
#  'b100-43650': Sentence(words=('I', 'told', 'Ben', 'so', '.'), tags=('PRON', 'VERB', 'NOUN', 'ADV', '.')),
#  'b100-34783': Sentence(words=('Because', 'of', 'the', 'uncertainty', 'of', 'this', 'definition', ',', 'I', 'solicited', 'the', 'interpretation', 'of', 'the', 'Secretary', 'of', 'Labor', '.'), tags=('ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-18885': Sentence(words=('``', "Shootin'", "'em", 'out', "''", 'was', "gettin'", 'cattle', 'out', 'of', 'a', 'corral', 'onto', 'the', 'range', '.'), tags=('.', 'VERB', 'PRON', 'PRT', '.', 'VERB', 'VERB', 'NOUN', 'ADP', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-16482': Sentence(words=('To', 'help', 'prevent', 'orthodontic', 'problems', 'from', 'arising', ',', 'your', 'dentist', 'can', 'do', 'these', 'things', ':'), tags=('PRT', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADP', 'VERB', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.')),
#  'b100-2505': Sentence(words=('The', 'decoration', 'will', 'be', 'presented', 'by', 'A.', 'Trichieri', ',', 'Italian', 'consul', 'general', 'in', 'Boston', ',', 'at', 'a', 'ceremony', 'at', '30', 'p.m.', 'on', 'Dec.', '7', 'at', 'the', 'plant', ',', 'which', 'this', 'year', 'is', 'celebrating', 'its', 'golden', 'anniversary', '.'), tags=('DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'ADV', 'ADP', 'NOUN', 'NUM', 'ADP', 'DET', 'NOUN', '.', 'DET', 'DET', 'NOUN', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', '.')),
#  'b100-37765': Sentence(words=('The', 'specimen', 'of', 'fabric', 'is', 'a', 'rectangle', 'at', 'least', '22', 'by', '22', 'inches', ',', 'except', 'for', 'cloth', 'narrower', 'than', '22', 'inches', ',', 'in', 'which', 'case', 'the', 'specimen', 'is', 'the', 'entire', 'width', 'of', 'the', 'fabric', '.'), tags=('DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'NUM', 'ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADP', 'NOUN', 'ADJ', 'ADP', 'NUM', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-15686': Sentence(words=('Clerks', 'and', 'postmasters', 'shoveled', 'muck', 'out', 'of', 'their', 'offices', '--', 'those', 'who', 'still', 'had', 'offices', '--', 'and', 'wondered', 'how', 'to', 'move', 'the', 'mail', '.'), tags=('NOUN', 'CONJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'ADP', 'DET', 'NOUN', '.', 'DET', 'PRON', 'ADV', 'VERB', 'NOUN', '.', 'CONJ', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.')),
#  'b100-38343': Sentence(words=('Prevot', 'had', 'briefed', 'the', 'two', 'new', 'men', 'that', 'afternoon', '.'), tags=('NOUN', 'VERB', 'VERB', 'DET', 'NUM', 'ADJ', 'NOUN', 'DET', 'NOUN', '.')),
#  'b100-46286': Sentence(words=('now', 'he', 'felt', 'light', 'and', 'gay', 'and', 'clear-headed', ',', 'ready', 'for', 'the', 'many', 'actions', 'he', 'saw', 'spreading', 'out', 'before', 'him', '.'), tags=('ADV', 'PRON', 'VERB', 'ADJ', 'CONJ', 'ADJ', 'CONJ', 'ADJ', '.', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRT', 'ADP', 'PRON', '.')),
#  'b100-6950': Sentence(words=('All', 'of', 'which', 'makes', 'it', 'more', 'imperative', 'than', 'ever', 'that', 'the', 'biological', 'and', 'genetic', 'effects', 'of', 'fallout', 'be', 'understood', '.'), tags=('PRT', 'ADP', 'DET', 'VERB', 'PRON', 'ADV', 'ADJ', 'ADP', 'ADV', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', '.')),
#  'b100-30738': Sentence(words=('All', 'subsequent', 'measurements', 'were', 'made', 'on', 'material', 'which', 'had', 'been', 'heated', 'to', '375-degrees-C', 'for', 'one', 'hour', '.'), tags=('PRT', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'DET', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'NUM', 'NOUN', '.')),
#  'b100-52856': Sentence(words=('They', 'chanted', 'a', 'fixed', 'tune', 'in', 'time', 'to', 'the', 'report', 'of', 'the', 'stick', '.'), tags=('PRON', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-9335': Sentence(words=('Keys', 'has', 'no', 'such', 'objections', 'to', 'Metrecal', ',', 'Quaker', "Oats's", 'Quota', 'and', 'other', '900-calorie', 'milk', 'formulas', 'that', 'are', 'currently', 'winning', 'favor', 'from', 'dieters', '.'), tags=('NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'ADJ', 'ADJ', 'NOUN', 'NOUN', 'PRON', 'VERB', 'ADV', 'VERB', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-16297': Sentence(words=('For', 'Mrs.', 'Shaefer', '--', 'who', 'had', 'been', 'given', 'a', 'clean', 'bill', 'of', 'health', 'by', 'her', 'own', 'physician', 'at', 'the', 'time', 'she', 'visited', 'Lee', '--', 'and', 'her', 'friend', 'were', 'agents', 'for', 'the', 'California', 'Pure', 'Food', 'and', 'Drug', 'Inspection', 'Bureau', '.'), tags=('ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'NOUN', '.')),
#  'b100-28058': Sentence(words=('All', 'of', 'its', 'cities', 'close', 'their', 'fiscal', 'years', 'on', 'December', '31', '.'), tags=('PRT', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NUM', '.')),
#  'b100-32062': Sentence(words=('On', 'the', 'other', 'hand', ',', 'the', 'null', 'space', 'of', 'Af', 'and', 'the', 'null', 'space', 'of', 'Af', 'together', 'span', 'V', ',', 'the', 'former', 'being', 'the', 'subspace', 'spanned', 'by', 'Af', 'and', 'the', 'latter', 'the', 'subspace', 'spanned', 'by', 'Af', 'and', 'Af', '.'), tags=('ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADV', 'VERB', 'NOUN', '.', 'DET', 'ADJ', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'CONJ', 'DET', 'ADJ', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.')),
#  'b100-21712': Sentence(words=('The', 'person', 'of', 'the', 'artist', 'becomes', 'a', 'final', 'bastion', 'of', 'meaning', 'in', 'a', 'world', 'rendered', 'meaningless', 'by', 'the', 'march', 'of', 'events', 'and', 'the', 'decay', 'of', 'classical', 'religious', 'and', 'philosophical', 'systems', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'CONJ', 'ADJ', 'NOUN', '.')),
#  'b100-17882': Sentence(words=('The', 'consequence', 'of', 'this', 'is', 'that', 'the', 'girls', 'at', 'Brooklyn', 'College', 'outnumber', 'the', 'boys', 'and', 'do', 'somewhat', 'better', 'academically', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'CONJ', 'VERB', 'ADV', 'ADV', 'ADV', '.')),
#  'b100-16336': Sentence(words=('After', 'his', 'pains', 'got', 'worse', ',', 'Tom', 'decided', 'to', 'see', 'a', 'real', 'doctor', ',', 'from', 'whom', 'he', 'learned', 'he', 'was', 'suffering', 'from', 'cancer', 'of', 'the', 'lung', '.'), tags=('ADP', 'DET', 'NOUN', 'VERB', 'ADJ', '.', 'NOUN', 'VERB', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'PRON', 'VERB', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.')),
#  'b100-2095': Sentence(words=('Robinson', 'told', 'Policemen', 'James', 'Jones', 'and', 'Morgan', 'Lloyd', 'of', 'the', 'Wabash', 'Avenue', 'district', 'that', '10', 'youths', 'boarded', 'his', 'south', 'bound', 'express', 'bus', 'in', 'front', 'of', 'Dunbar', 'Vocational', 'High', 'School', ',', '30th', 'Street', 'and', 'South', 'Park', 'Way', ',', 'and', 'began', '``', 'skylarking', "''", '.'), tags=('NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NUM', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'ADJ', 'NOUN', '.', 'ADJ', 'NOUN', 'CONJ', 'ADJ', 'NOUN', 'NOUN', '.', 'CONJ', 'VERB', '.', 'VERB', '.', '.')),
#  'b100-31545': Sentence(words=('It', 'is', ',', 'however', ',', 'highly', 'suggestive', 'and', 'agrees', 'well', 'with', 'our', 'own', 'findings', 'in', 'which', 'we', 'also', 'failed', 'to', 'demonstrate', 'normally', 'occurring', 'bronchial', 'artery-pulmonary', 'artery', 'shunts', 'in', 'certain', 'species', ',', 'especially', 'the', 'dog', '.'), tags=('PRON', 'VERB', '.', 'ADV', '.', 'ADV', 'ADJ', 'CONJ', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'PRON', 'ADV', 'VERB', 'PRT', 'VERB', 'ADV', 'VERB', 'ADJ', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'ADV', 'DET', 'NOUN', '.')),
#  'b100-47833': Sentence(words=('What', 'do', 'we', 'care', "''", '?', '?'), tags=('PRON', 'VERB', 'PRON', 'VERB', '.', '.', '.')),
#  'b100-2729': Sentence(words=('Registrations', 'of', 'new', 'cars', 'in', 'Dallas', 'County', 'cracked', 'the', '3,000', 'mark', 'in', 'March', 'for', 'the', 'first', 'time', 'this', 'year', '.'), tags=('NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'DET', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', '.')),
#  'b100-16761': Sentence(words=('In', 'other', 'words', ',', 'the', 'promulgators', 'of', 'the', 'murder', 'plan', 'made', 'clear', 'that', 'physically', 'exterminating', 'the', 'Jews', 'was', 'but', 'an', 'extension', 'of', 'the', 'anti-Semitic', 'measures', 'already', 'operating', 'in', 'every', 'phase', 'of', 'German', 'life', ',', 'and', 'that', 'the', 'new', 'conspiracy', 'counted', 'on', 'the', 'general', 'anti-Semitism', 'that', 'had', 'made', 'those', 'measures', 'effective', ',', 'as', 'a', 'readiness', 'for', 'murder', '.'), tags=('ADP', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'ADP', 'ADV', 'VERB', 'DET', 'NOUN', 'VERB', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'DET', 'NOUN', 'ADJ', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-2141': Sentence(words=('While', 'neighbor', 'women', 'assumed', 'some', 'of', 'the', 'dead', "mother's", 'duties', ',', 'fund-raising', 'events', 'were', 'being', 'planned', 'by', 'a', 'homeowners', 'association', 'and', 'a', 'student', 'council', 'for', 'the', 'hard-hit', 'Henry', 'Kowalski', 'family', ',', '34220', 'Viceroy', '.'), tags=('ADP', 'NOUN', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'CONJ', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.', 'NUM', 'NOUN', '.')),
#  'b100-8761': Sentence(words=('The', 'mushrooming', 'of', 'FM', 'outlets', ',', 'offering', 'concerts', '(', 'both', 'jazz', 'and', 'classical', ')', ',', 'lectures', ',', 'and', 'other', 'special', 'events', ',', 'is', 'a', 'phenomenon', 'which', 'has', 'had', 'a', 'fair', 'amount', 'of', 'publicity', '.'), tags=('DET', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'VERB', 'NOUN', '.', 'DET', 'NOUN', 'CONJ', 'ADJ', '.', '.', 'NOUN', '.', 'CONJ', 'ADJ', 'ADJ', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'DET', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.')),
#  'b100-31692': Sentence(words=('Antithyroid', 'drugs', 'are', 'of', 'two', 'general', 'types', '.'), tags=('ADJ', 'NOUN', 'VERB', 'ADP', 'NUM', 'ADJ', 'NOUN', '.')),
#  'b100-21518': Sentence(words=('Side', 'fences', 'were', 'hidden', 'beneath', 'lilacs', 'and', 'hundred-leaf', 'roses', ';', ';'), tags=('ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.', '.')),
#  ...}

# %%
type(data.training_set[0])
# Out:
# dict

# %% [markdown]
# ### The Dataset Interface
#
# You can access (mostly) immutable references to the dataset through a simple interface provided through the `Dataset` class, which represents an iterable collection of sentences along with easy access to partitions of the data for training & testing. Review the reference below, then run and review the next few cells to make sure you understand the interface before moving on to the next step.
#
# ```
# Dataset-only Attributes:
#     training_set - reference to a Subset object containing the samples for training
#     testing_set - reference to a Subset object containing the samples for testing
#
# Dataset & Subset Attributes:
#     sentences - a dictionary with an entry {sentence_key: Sentence()} for each sentence in the corpus
#     keys - an immutable ordered (not sorted) collection of the sentence_keys for the corpus
#     vocab - an immutable collection of the unique words in the corpus
#     tagset - an immutable collection of the unique tags in the corpus
#     X - returns an array of words grouped by sentences ((w11, w12, w13, ...), (w21, w22, w23, ...), ...)
#     Y - returns an array of tags grouped by sentences ((t11, t12, t13, ...), (t21, t22, t23, ...), ...)
#     N - returns the number of distinct samples (individual words or tags) in the dataset
#
# Methods:
#     stream() - returns an flat iterable over all (word, tag) pairs across all sentences in the corpus
#     __iter__() - returns an iterable over the data as (sentence_key, Sentence()) pairs
#     __len__() - returns the nubmer of sentences in the dataset
# ```
#
# For example, consider a Subset, `subset`, of the sentences `{"s0": Sentence(("See", "Spot", "run"), ("VERB", "NOUN", "VERB")), "s1": Sentence(("Spot", "ran"), ("NOUN", "VERB"))}`. The subset will have these attributes:
#
# ```
# subset.keys == {"s1", "s0"}  # unordered
# subset.vocab == {"See", "run", "ran", "Spot"}  # unordered
# subset.tagset == {"VERB", "NOUN"}  # unordered
# subset.X == (("Spot", "ran"), ("See", "Spot", "run"))  # order matches .keys
# subset.Y == (("NOUN", "VERB"), ("VERB", "NOUN", "VERB"))  # order matches .keys
# subset.N == 7  # there are a total of seven observations over all sentences
# len(subset) == 2  # because there are two sentences
# ```
#
# <div class="alert alert-block alert-info">
# **Note:** The `Dataset` class is _convenient_, but it is **not** efficient. It is not suitable for huge datasets because it stores multiple redundant copies of the same data.
# </div>

# %% [markdown]
# #### Sentences
#
# `Dataset.sentences` is a dictionary of all sentences in the training corpus, each keyed to a unique sentence identifier. Each `Sentence` is itself an object with two attributes: a tuple of the words in the sentence named `words` and a tuple of the tag corresponding to each word named `tags`.

# %%
key = 'b100-38532'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: b100-38532
# words:
# 	('Perhaps', 'it', 'was', 'right', ';', ';')
# tags:
# 	('ADV', 'PRON', 'VERB', 'ADJ', '.', '.')

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** The underlying iterable sequence is **unordered** over the sentences in the corpus; it is not guaranteed to return the sentences in a consistent order between calls. Use `Dataset.stream()`, `Dataset.keys`, `Dataset.X`, or `Dataset.Y` attributes if you need ordered access to the data.
# </div>
#
# #### Counting Unique Elements
#
# You can access the list of unique words (the dataset vocabulary) via `Dataset.vocab` and the unique list of tags via `Dataset.tagset`.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 1161192 samples of 56057 unique words in the corpus.
# There are 928458 samples of 50536 unique words in the training set.
# There are 232734 samples of 25112 unique words in the testing set.
# There are 5521 words in the test set that are missing in the training set.

# %% [markdown]
# #### Accessing word and tag Sequences
# The `Dataset.X` and `Dataset.Y` attributes provide access to ordered collections of matching word and tag sequences for each sentence in the dataset.

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.')
#
# Labels 1: ('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
# Sentence 2: ('But', 'there', 'seemed', 'to', 'be', 'some', 'difference', 'of', 'opinion', 'as', 'to', 'how', 'far', 'the', 'board', 'should', 'go', ',', 'and', 'whose', 'advice', 'it', 'should', 'follow', '.')
#
# Labels 2: ('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.')

# %% [markdown]
# #### Accessing (word, tag) Samples
# The `Dataset.stream()` method returns an iterator that chains together every pair of (word, tag) entries across all sentences in the entire corpus.

# %%
# use Dataset.stream() (word, tag) samples for the entire corpus
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 5: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('Mr.', 'NOUN')
# 	 ('Podger', 'NOUN')
# 	 ('had', 'VERB')
# 	 ('thanked', 'VERB')
# 	 ('him', 'PRON')
# 	 ('gravely', 'ADV')
# 	 (',', '.')

# %% [markdown]
# For both our baseline tagger and the HMM model we'll build, we need to estimate the frequency of tags & words from the frequency counts of observations in the training corpus. In the next several cells you will complete functions to compute the counts of several sets of counts.

# %% [markdown]
# ## Step 2: Build a Most Frequent Class tagger
# ---
#
# Perhaps the simplest tagger (and a good baseline for tagger performance) is to simply choose the tag most frequently assigned to each word. This "most frequent class" tagger inspects each observed word in the sequence and assigns it the label that was most often assigned to that word in the corpus.

# %% [markdown]
# ### IMPLEMENTATION: Pair Counts
#
# Complete the function below that computes the joint frequency counts for two input sequences.

# %% [markdown]
# len(data.X)
#
# pos = set()
# for i in range(len(data.Y)):
#     for var in data.Y[i]:
#         test.add(var)
#
# test
#
# abc[test] = 0
#
# abc = {}
# abc['noun'] = {}
# abc['noun']['kim'] = 100
# abc['noun']['john'] = 20
#
# print(len(abc))
#
# abc['noun']['kim']
#
# test = set()
# for i in range(len(data.Y)):
#     for var in data.Y[i]:
# m        test.add(var)
#
# test_list = list(test)
#
# print(test_list[0])
#
# count_dict = {}
# for i, pair in enumerate(data.stream()):
#     print(pair)
#     count_dict[pair[1]] = {}
#     count_dict[pair[1]][pair[0]] = count_dict.get(pair[0],0) +1
#     if i > 100: break
#
# print(count_dict.get)
#
# data.X[0]
#
# test_list = ['noun','verb','modal']
# test_dict = {}
# for i in test_list:
#     test_dict[i] = {}
#     test_dict[i].setdefault(i, 0)
#
# print(test_dict)
#
# len(data.X[0])
#
# i = 0
# for sentence in data.X:
#     for word in sentence:
#         print(word)
#         i += 1
#         if i > 100: break

# %%
tag_word_counter={}
#int i = 0
for i, pair in enumerate(zip(data.X[:40], data.Y[:40])):
    for tag in pair[1]:
        if tag not in tag_word_counter.keys():
            tag_word_counter[tag] = {}
            
    for word in pair[0]:
        try:
            tag_word_counter[tag][word] += 1
        except KeyError:
            tag_word_counter[tag][word] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-073184c52abc> in <module>()
#       1 tag_word_counter={}
#       2 #int i = 0
# ----> 3 for i, pair in enumerate(zip(data.X[:40], data.Y[:40])):
#       4     for tag in pair[1]:
#       5         if tag not in tag_word_counter.keys():
#
# NameError: name 'data' is not defined

# %%
tag_word_counter

# %%
tag_word_counter = defaultdict(dict)
for i, pair in enumerate(zip(data.X[:40], data.Y[:40])):
    tag_word_counter[pair[1]][pair[0]] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-a1e25fd7b119> in <module>()
#       1 tag_word_counter = defaultdict(dict)
#       2 for i, pair in enumerate(zip(data.X[:40], data.Y[:40])):
# ----> 3     tag_word_counter[pair[1]][pair[0]] += 1
#
# KeyError: ('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.')

# %%
print(tag_word_counter)
# Out:
# defaultdict(<class 'dict'>, {('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.'): {}})

# %%
pos=('noun','verb')
pos_list = list(pos)
tag_word_counter = {}
for pos in pos_list:
    tag_word_counter[pos] = 0

# %%
print(tag_word_counter)
# Out:
# {'noun': 0, 'verb': 0}

# %%
def pair_counts(sequences_A, sequences_B):
    """Return a dictionary keyed to each unique value in the first sequence list
    that counts the number of occurrences of the corresponding value from the
    second sequences list.
    
    For example, if sequences_A is tags and sequences_B is the corresponding
    words, then if 1244 sequences contain the word "time" tagged as a NOUN, then
    you should return a dictionary such that pair_counts[NOUN][time] == 1244
    """
    # TODO: Finish this function!
    tag_word_counter={}

    for i, pair in enumerate(zip(sequences_B, sequences_A)):
        for tag in pair[1]:
            if tag not in tag_word_counter.keys():
                tag_word_counter[tag] = {}
            
        for word in pair[0]:
            try:
                tag_word_counter[tag][word] += 1
            except KeyError:
                tag_word_counter[tag][word] = 1
            
    
#     tag_word_counter_2 = {}
#     pos = set()
#     for i in range(len(data.Y)):
#         for var in data.Y[i]:
#             pos.add(var)
#     pos_list = list(pos)
#     for pos in pos_list:
#         tag_word_counter_2[pos] = {}
#     for i, pair in enumerate(zip(sequences_A, sequences_B)):
#          for ii, tag in enumerate(pair[0]):
#                 try:
#                     tag_word_counter_2[tag][pair[1][ii]] += 1
#                 except:
#                     tag_word_counter_2[tag][pair[1][ii]] = 1
    return tag_word_counter #tag_word_counter

# %%
# Calculate C(t_i, w_i)
emission_counts = pair_counts(data.Y, data.X)

assert len(emission_counts) == 12, \
       "Uh oh. There should be 12 tags in your dictionary."
assert max(emission_counts["NOUN"], key=emission_counts["NOUN"].get) == 'time', \
       "Hmmm...'time' is expected to be the most common NOUN."
HTML('<div class="alert alert-block alert-success">Your emission counts look good!</div>')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-36-2967dd4fe8fc> in <module>()
#       3
#       4 assert len(emission_counts) == 12,        "Uh oh. There should be 12 tags in your dictionary."
# ----> 5 assert max(emission_counts["NOUN"], key=emission_counts["NOUN"].get) == 'time',        "Hmmm...'time' is expected to be the most common NOUN."
#       6 HTML('<div class="alert alert-block alert-success">Your emission counts look good!</div>')
#
# AssertionError: Hmmm...'time' is expected to be the most common NOUN.

# %% [markdown]
# ### IMPLEMENTATION: Most Frequent Class Tagger
#
# Use the `pair_counts()` function and the training dataset to find the most frequent class label for each word in the training data, and populate the `mfc_table` below. The table keys should be words, and the values should be the appropriate tag string.
#
# The `MFCTagger` class is provided to mock the interface of Pomegranite HMM models so that they can be used interchangeably.

# %% [markdown]
# word_counts = pair_counts(data.training_set.Y, data.training_set.X)
#
# import pprint
#
# flipped = defaultdict(dict)
# for key, vals in word_counts.items():
#     for subkey, subval in vals.items():
#         flipped[subkey][key] = subval
#
#
# pprint.pprint(dict(flipped))
#
# test = defaultdict(dict)
# test['aaa']['NOUN'] = 1
# test['bbb']['NOUN'] = 2
# test['ccc']['VERB'] = 3
# test['ddd']['CONJ'] = 4
# test['aaa']['VERB'] = 3
#
# print(max(test['aaa']))
#
#
# test
#
# len(test)
#
# for key, vals in test.items():
#     print(key)
#     print(vals)
#     print(max(test[key]))

# %%
# Create a lookup table mfc_table where mfc_table[word] contains the tag label most frequently assigned to that word
from collections import namedtuple

FakeState = namedtuple("FakeState", "name")

class MFCTagger:
    # NOTE: You should not need to modify this class or any of its methods
    missing = FakeState(name="<MISSING>")
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))


# TODO: calculate the frequency of each tag being assigned to each word (hint: similar, but not
# the same as the emission probabilities) and use it to fill the mfc_table

word_counts = pair_counts(data.training_set.Y, data.training_set.X)

tag_word_counts = defaultdict(dict)
for key, vals in word_counts.items(): # [POS] ([Word],counts)
    for subkey, subval in vals.items(): # {Word], counts
        tag_word_counts[subkey][key] = subval 

mfc_table = defaultdict(int)
for key, vals in tag_word_counts.items():
    max_pos = max(tag_word_counts[key])
    mfc_table[key] = max_pos
    
# DO NOT MODIFY BELOW THIS LINE
mfc_model = MFCTagger(mfc_table) # Create a Most Frequent Class tagger instance

assert len(mfc_table) == len(data.training_set.vocab), ""
assert all(k in data.training_set.vocab for k in mfc_table.keys()), ""
assert sum(int(k not in mfc_table) for k in data.testing_set.vocab) == 5521, ""
HTML('<div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>')
# Out:
# <div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>

# %% [markdown]
# ### Making Predictions with a Model
# The helper functions provided below interface with Pomegranate network models & the mocked MFCTagger to take advantage of the [missing value](http://pomegranate.readthedocs.io/en/latest/nan.html) functionality in Pomegranate through a simple sequence decoding function. Run these functions, then run the next cell to see some of the predictions made by the MFC tagger.

# %%
def replace_unknown(sequence):
    """Return a copy of the input sequence where each unknown word is replaced
    by the literal string value 'nan'. Pomegranate will ignore these values
    during computation.
    """
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):
    """X should be a 1-D sequence of observations for the model to predict"""
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]  # do not show the start/end state predictions

# %% [markdown]
# ### Example Decoding Sequences with MFC Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Predicted labels:
# -----------------
# ['X', 'NOUN', 'NUM', 'X', 'NOUN', 'NUM', 'X', 'NOUN', 'NUM', 'X', 'X', 'VERB', 'NUM', 'X', 'X', 'NOUN', 'X', '.']
#
# Actual labels:
# --------------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')
#
#
# Sentence Key: b100-23146
#
# Predicted labels:
# -----------------
# ['PRON', 'VERB', 'X', 'NOUN', 'X', 'ADJ', 'ADJ', 'NOUN', 'X', 'VERB', 'X', 'X', 'VERB', 'PRON', 'NOUN', 'X', 'NOUN', 'PRT', 'X', 'VERB', '.']
#
# Actual labels:
# --------------
# ('PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
#
# Sentence Key: b100-35462
#
# Predicted labels:
# -----------------
# ['DET', 'ADJ', 'NOUN', 'X', 'X', 'VERB', 'ADP', 'X', 'ADJ', 'ADJ', 'VERB', 'X', 'X', 'NOUN', 'NOUN', 'X', 'ADP', 'ADJ', 'NOUN', 'X', 'X', 'ADP', 'X', '<MISSING>', 'X', 'ADV', 'NOUN', 'X', 'ADJ', 'X', 'X', 'ADJ', 'NOUN', 'X', 'ADV', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')

# %% [markdown]
# ### Evaluating Model Accuracy
#
# The function below will evaluate the accuracy of the MFC tagger on the collection of all sentences from a text corpus.

# %%
def accuracy(X, Y, model):
    """Calculate the prediction accuracy by using the model to decode each sequence
    in the input X and comparing the prediction with the true labels in Y.
    
    The X should be an array whose first dimension is the number of sentences to test,
    and each element of the array should be an iterable of the words in the sequence.
    The arrays X and Y should have the exact same shape.
    
    X = [("See", "Spot", "run"), ("Run", "Spot", "run", "fast"), ...]
    Y = [(), (), ...]
    """
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %% [markdown]
# #### Evaluate the accuracy of the MFC tagger
# Run the next cell to evaluate the accuracy of the tagger on the training and test corpus.

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))

assert mfc_training_acc >= 0.955, "Uh oh. Your MFC accuracy on the training set doesn't look right."
assert mfc_testing_acc >= 0.925, "Uh oh. Your MFC accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>')
# Out:
# training accuracy mfc_model: 56.32%
# testing accuracy mfc_model: 53.51%
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-32-08df9625ea72> in <module>()
#       5 print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
#       6
# ----> 7 assert mfc_training_acc >= 0.955, "Uh oh. Your MFC accuracy on the training set doesn't look right."
#       8 assert mfc_testing_acc >= 0.925, "Uh oh. Your MFC accuracy on the testing set doesn't look right."
#       9 HTML('<div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>')
#
# AssertionError: Uh oh. Your MFC accuracy on the training set doesn't look right.

# %% [markdown]
# ## Step 3: Build an HMM tagger
# ---
# The HMM tagger has one hidden state for each possible tag, and parameterized by two distributions: the emission probabilties giving the conditional probability of observing a given **word** from each hidden state, and the transition probabilities giving the conditional probability of moving between **tags** during the sequence.
#
# We will also estimate the starting probability distribution (the probability of each **tag** being the first tag in a sequence), and the terminal probability distribution (the probability of each **tag** being the last tag in a sequence).
#
# The maximum likelihood estimate of these distributions can be calculated from the frequency counts as described in the following sections where you'll implement functions to count the frequencies, and finally build the model. The HMM model will make predictions according to the formula:
#
# $$t_i^n = \underset{t_i^n}{\mathrm{argmin}} \prod_{i=1}^n P(w_i|t_i) P(t_i|t_{i-1})$$
#
# Refer to Speech & Language Processing [Chapter 10](https://web.stanford.edu/~jurafsky/slp3/10.pdf) for more information.

# %% [markdown]
# ### IMPLEMENTATION: Unigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each symbol over all of the input sequences. The unigram probabilities in our HMM model are estimated from the formula below, where N is the total number of samples in the input. (You only need to compute the counts for now.)
#
# $$P(tag_1) = \frac{C(tag_1)}{N}$$

# %%
def unigram_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequence list that
    counts the number of occurrences of the value in the sequences list. The sequences
    collection should be a 2-dimensional array.
    
    For example, if the tag NOUN appears 275558 times over all the input sequences,
    then you should return a dictionary such that your_unigram_counts[NOUN] == 275558.
    """
    # TODO: Finish this function!
    total_pos_list = []
    for i, x in enumerate(sequences):
        for ii, tag in enumerate(x):
            total_pos_list.append(tag)
            
    tag_counter = Counter(total_pos_list)
    return tag_counter

# TODO: call unigram_counts with a list of tag sequences from the training set
tag_unigrams = unigram_counts(data.Y)

assert set(tag_unigrams.keys()) == data.training_set.tagset, \
       "Uh oh. It looks like your tag counts doesn't include all the tags!"
assert min(tag_unigrams, key=tag_unigrams.get) == 'X', \
       "Hmmm...'X' is expected to be the least common class"
assert max(tag_unigrams, key=tag_unigrams.get) == 'NOUN', \
       "Hmmm...'NOUN' is expected to be the most common class"
HTML('<div class="alert alert-block alert-success">Your tag unigrams look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your tag unigrams look good!</div>

# %%
print(tag_unigrams['NOUN'])
for tag in tag_unigrams:
    print(tag_unigrams[tag])
# Out:
# 275558
# 275558
# 182750
# 49334
# 56239
# 147565
# 38151
# 144766
# 137019
# 29829
# 83721
# 1386
# 14874

# %% [markdown]
# ### IMPLEMENTATION: Bigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each pair of symbols in each of the input sequences. These counts are used in the HMM model to estimate the bigram probability of two tags from the frequency counts according to the formula: $$P(tag_2|tag_1) = \frac{C(tag_2|tag_1)}{C(tag_2)}$$

# %%
tag_list = [tag for i, (word, tag) in enumerate(data.stream())]
sequence_pair = list(zip(tag_list[:-1], tag_list[1:]))
print(sequence_pair[:10])
# Out:
# [('NOUN', 'NOUN'), ('NOUN', 'VERB'), ('VERB', 'VERB'), ('VERB', 'PRON'), ('PRON', 'ADV'), ('ADV', '.'), ('.', 'CONJ'), ('CONJ', 'ADV'), ('ADV', 'PRON'), ('PRON', 'VERB')]

# %%
print(tag_list[:100])
# Out:
# ['NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.', 'PRT', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADJ', 'ADP', 'VERB', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'ADJ', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', '.', 'NOUN', '.', '.', '.', 'NOUN', '.', '.', '.', 'NOUN', '.', '.']

# %%
x = [1,2,3,4,5]
pairs = list(zip(x[:-1], x[1:]))
print(pairs)
print(x[:-1])
# Out:
# [(1, 2), (2, 3), (3, 4), (4, 5)]
# [1, 2, 3, 4]

# %%
def bigram_counts(sequences):
    """Return a dictionary keyed to each unique PAIR of values in the input sequences
    list that counts the number of occurrences of pair in the sequences list. The input
    should be a 2-dimensional array.
    
    For example, if the pair of tags (NOUN, VERB) appear 61582 times, then you should
    return a dictionary such that your_bigram_counts[(NOUN, VERB)] == 61582
    """

    # TODO: Finish this function!
    # First Answer
    # Assumption : parameter sequence is data.Y
#     bigram_counter = Counter()
#     for i, x in enumerate(sequences):
#         for ii in range(len(x)-1):
#             bigram_counter[(x[ii],x[ii+1])] += 1
    
#     return bigram_counter
    
    # Second Answer
    # Assumption : parameter sequence is data.stream()
    bigram_counter = Counter()
    tag_list = [tag for i, (word, tag) in enumerate(sequences)]
    sequence_pair = list(zip(tag_list[:-1], tag_list[1:]))
    for pair in sequence_pair:
        bigram_counter[pair] += 1
        
    return bigram_counter

# TODO: call bigram_counts with a list of tag sequences from the training set
# tag_bigrams = bigram_counts(data.Y) # First Answer
tag_bigrams = bigram_counts(data.stream()) # Second Answer
assert len(tag_bigrams) == 144, \
       "Uh oh. There should be 144 pairs of bigrams (12 tags x 12 tags)"
assert min(tag_bigrams, key=tag_bigrams.get) in [('X', 'NUM'), ('PRON', 'X')], \
       "Hmmm...The least common bigram should be one of ('X', 'NUM') or ('PRON', 'X')."
assert max(tag_bigrams, key=tag_bigrams.get) in [('DET', 'NOUN')], \
       "Hmmm...('DET', 'NOUN') is expected to be the most common bigram."
HTML('<div class="alert alert-block alert-success">Your tag bigrams look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your tag bigrams look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Sequence Starting Counts
# Complete the code below to estimate the bigram probabilities of a sequence starting with each tag.

# %%
def starting_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the beginning of
    a sequence.
    
    For example, if 8093 sequences start with NOUN, then you should return a
    dictionary such that your_starting_counts[NOUN] == 8093
    """
    # TODO: Finish this function!
    starting_counter = Counter()
    for i, x in enumerate(sequences):
        starting_counter[x[0]] += 1
    return starting_counter
        

# TODO: Calculate the count of each tag starting a sequence
tag_starts = starting_counts(data.Y)

assert len(tag_starts) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_starts, key=tag_starts.get) == 'X', "Hmmm...'X' is expected to be the least common starting bigram."
assert max(tag_starts, key=tag_starts.get) == 'DET', "Hmmm...'DET' is expected to be the most common starting bigram."
HTML('<div class="alert alert-block alert-success">Your starting tag counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your starting tag counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Sequence Ending Counts
# Complete the function below to estimate the bigram probabilities of a sequence ending with each tag.

# %%
for i, x in enumerate(data.Y[0:2]):
    print(x)
    print()
    print(x[len(x)-1])
# Out:
# ('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
# .
# ('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.')
#
# .

# %%
def ending_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the end of
    a sequence.
    
    For example, if 18 sequences end with DET, then you should return a
    dictionary such that your_starting_counts[DET] == 18
    """
    # TODO: Finish this function!
    ending_counter = Counter()
    for i, x in enumerate(sequences):
        ending_counter[x[len(x)-1]] += 1
        
    return ending_counter

# TODO: Calculate the count of each tag ending a sequence
tag_ends = ending_counts(data.Y)

assert len(tag_ends) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_ends, key=tag_ends.get) in ['X', 'CONJ'], "Hmmm...'X' or 'CONJ' should be the least common ending bigram."
assert max(tag_ends, key=tag_ends.get) == '.', "Hmmm...'.' is expected to be the most common ending bigram."
HTML('<div class="alert alert-block alert-success">Your ending tag counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your ending tag counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Basic HMM Tagger
# Use the tag unigrams and bigrams calculated above to construct a hidden Markov tagger.
#
# - Add one state per tag
#     - The emission distribution at each state should be estimated with the formula: $P(w|t) = \frac{C(t, w)}{C(t)}$
# - Add an edge from the starting state `basic_model.start` to each tag
#     - The transition probability should be estimated with the formula: $P(t|start) = \frac{C(start, t)}{C(start)}$
# - Add an edge from each tag to the end state `basic_model.end`
#     - The transition probability should be estimated with the formula: $P(end|t) = \frac{C(t, end)}{C(t)}$
# - Add an edge between _every_ pair of tags
#     - The transition probability should be estimated with the formula: $P(t_2|t_1) = \frac{C(t_1, t_2)}{C(t_1)}$

# %%
t_w_counter = Counter()
for i, (word, tag) in enumerate(data.stream()):
    t_w_counter[(word, tag)] += 1
    b
# Out:
# Counter({('the', 'DET'): 62710, (',', '.'): 58333, ('.', '.'): 49346, ('of', 'ADP'): 36078, ('and', 'CONJ'): 27912, ('a', 'DET'): 21872, ('in', 'ADP'): 19066, ('to', 'PRT'): 14742, ('to', 'ADP'): 10985, ('is', 'VERB'): 10010, ('was', 'VERB'): 9777, ('``', '.'): 8837, ('for', 'ADP'): 8833, ("''", '.'): 8789, ('The', 'DET'): 7258, ('with', 'ADP'): 7009, ('it', 'PRON'): 6722, ('he', 'PRON'): 6564, ('his', 'DET'): 6428, ('that', 'ADP'): 6422, ('be', 'VERB'): 6342, ('on', 'ADP'): 5837, ('as', 'ADP'): 5656, (';', '.'): 5566, ('I', 'PRON'): 5155, ('had', 'VERB'): 5101, ('by', 'ADP'): 5044, ('at', 'ADP'): 4963, ('?', '.'): 4692, ('not', 'ADV'): 4423, ('are', 'VERB'): 4333, ('from', 'ADP'): 4207, ('or', 'CONJ'): 4117, ('this', 'DET'): 3965, ('have', 'VERB'): 3892, ('which', 'DET'): 3539, ('an', 'DET'): 3529, ('--', '.'): 3431, ('were', 'VERB'): 3279, ('He', 'PRON'): 2982, ('but', 'CONJ'): 2853, ('they', 'PRON'): 2773, ('you', 'PRON'): 2766, ('would', 'VERB'): 2677, ('him', 'PRON'): 2576, ('their', 'DET'): 2561, ('all', 'PRT'): 2548, ('been', 'VERB'): 2470, (')', '.'): 2456, ('(', '.'): 2425, ('has', 'VERB'): 2424, ('one', 'NUM'): 2389, ('who', 'PRON'): 2192, ('will', 'VERB'): 2105, ('It', 'PRON'): 2037, ('that', 'DET'): 1981, ('we', 'PRON'): 1973, ('she', 'PRON'): 1949, ('said', 'VERB'): 1943, ('In', 'ADP'): 1800, ('than', 'ADP'): 1788, ('its', 'DET'): 1780, ('that', 'PRON'): 1779, ('into', 'ADP'): 1779, ('her', 'DET'): 1779, ('them', 'PRON'): 1775, (':', '.'): 1773, ('when', 'ADV'): 1746, ('can', 'VERB'): 1730, ('up', 'PRT'): 1699, ('other', 'ADJ'): 1627, ('out', 'PRT'): 1620, ('!', '.'): 1596, ('could', 'VERB'): 1580, ('no', 'DET'): 1577, ('time', 'NOUN'): 1555, ('if', 'ADP'): 1465, ('what', 'DET'): 1435, ('some', 'DET'): 1388, ('But', 'CONJ'): 1371, ('there', 'PRT'): 1353, ('so', 'ADV'): 1336, ('two', 'NUM'): 1311, ('may', 'VERB'): 1290, ('any', 'DET'): 1288, ('only', 'ADV'): 1281, ('do', 'VERB'): 1259, ('about', 'ADP'): 1234, ('these', 'DET'): 1228, ('A', 'DET'): 1198, ('more', 'ADV'): 1188, ('This', 'DET'): 1179, ('me', 'PRON'): 1164, ('my', 'DET'): 1160, ('man', 'NOUN'): 1148, ('our', 'DET'): 1142, ('made', 'VERB'): 1119, ('her', 'PRON'): 1106, ('new', 'ADJ'): 1060, ('as', 'ADV'): 1049, ('now', 'ADV'): 1045, ('then', 'ADV'): 1008, ('also', 'ADV'): 999, ('must', 'VERB'): 998, ('Af', 'NOUN'): 994, ('did', 'VERB'): 994, ('like', 'ADP'): 991, ('first', 'ADJ'): 947, ('years', 'NOUN'): 942, ('more', 'ADJ'): 941, ('And', 'CONJ'): 938, ('even', 'ADV'): 931, ('She', 'PRON'): 911, ('such', 'ADJ'): 903, ('many', 'ADJ'): 896, ('way', 'NOUN'): 883, ('through', 'ADP'): 880, ('your', 'DET'): 868, ('should', 'VERB'): 865, ('where', 'ADV'): 850, ('They', 'PRON'): 847, ('Mr.', 'NOUN'): 844, ('over', 'ADP'): 820, ('after', 'ADP'): 812, ('There', 'PRT'): 811, ('people', 'NOUN'): 809, ('too', 'ADV'): 801, ('before', 'ADP'): 787, ('those', 'DET'): 782, ('make', 'VERB'): 765, ('each', 'DET'): 759, ('own', 'ADJ'): 750, ('men', 'NOUN'): 736, ('If', 'ADP'): 732, ('just', 'ADV'): 731, ('see', 'VERB'): 727, ('back', 'ADV'): 722, ('get', 'VERB'): 719, ('between', 'ADP'): 715, ('still', 'ADV'): 703, ('well', 'ADV'): 700, ('down', 'PRT'): 694, ('good', 'ADJ'): 693, ('world', 'NOUN'): 684, ('We', 'PRON'): 679, ('same', 'ADJ'): 679, ('very', 'ADV'): 678, ('life', 'NOUN'): 676, ('know', 'VERB'): 676, ('little', 'ADJ'): 673, ('most', 'ADV'): 673, ('us', 'PRON'): 670, ('because', 'ADP'): 667, ('never', 'ADV'): 664, ('being', 'VERB'): 663, ('might', 'VERB'): 658, ('For', 'ADP'): 648, ('year', 'NOUN'): 647, ('both', 'DET'): 643, ('under', 'ADP'): 632, ('how', 'ADV'): 623, ('day', 'NOUN'): 623, ('came', 'VERB'): 621, ('against', 'ADP'): 616, ('used', 'VERB'): 610, ('here', 'ADV'): 607, ('go', 'VERB'): 604, ('himself', 'PRON'): 599, ('great', 'ADJ'): 592, ('come', 'VERB'): 589, ('When', 'ADV'): 585, ('few', 'ADJ'): 583, ('work', 'NOUN'): 576, ('last', 'ADJ'): 575, ('New', 'ADJ'): 575, ('take', 'VERB'): 573, ('another', 'DET'): 573, ('old', 'ADJ'): 568, ('on', 'PRT'): 5 ...

# %%
i = 0
for current in t_w_counter:
    print(current)
    print(current[1])
    print(t_w_counter[current])
    i = i + 1
    if i >10 : break
# Out:
# ('Mr.', 'NOUN')
# NOUN
# 844
# ('Podger', 'NOUN')
# NOUN
# 21
# ('had', 'VERB')
# VERB
# 5101
# ('thanked', 'VERB')
# VERB
# 6
# ('him', 'PRON')
# PRON
# 2576
# ('gravely', 'ADV')
# ADV
# 7
# (',', '.')
# .
# 58333
# ('and', 'CONJ')
# CONJ
# 27912
# ('now', 'ADV')
# ADV
# 1045
# ('he', 'PRON')
# PRON
# 6564
# ('made', 'VERB')
# VERB
# 1119

# %%
basic_model_test = HiddenMarkovModel(name="base-hmm-tagger")
unigram = unigram_counts(sequences)
t_w_counter = Counter()
for i, (word, tag) in enumerate(data.stream()):
    t_w_counter[(word, tag)] += 1
for tag in unigram:
    state_distribution = {}
    for current in t_W_counter:
        if current[1] == tag:
            prob = t_w_counter[current]/unigram[tag]
            word = current[0]
            
        state_distribution[word] = prob
        
    emissions = DiscreteDistribution(state_distribution)
    State(emissons, name=tag)
    
print(State)

# %%
basic_model = HiddenMarkovModel(name="base-hmm-tagger")

# TODO: create states with emission probability distributions P(word | tag) and add to the model
# (Hint: you may need to loop & create/add new states)

basic_model.add_states()

# TODO: add edges between states for the observed transition frequencies P(tag_i | tag_i-1)
# (Hint: you may need to loop & add transitions
basic_model.add_transition()


# NOTE: YOU SHOULD NOT NEED TO MODIFY ANYTHING BELOW THIS LINE
# finalize the model
basic_model.bake()

assert all(tag in set(s.name for s in basic_model.states) for tag in data.training_set.tagset), \
       "Every state in your network should use the name of the associated tag, which must be one of the training set tags."
assert basic_model.edge_count() == 168, \
       ("Your network should have an edge from the start node to each state, one edge between every " +
        "pair of tags (states), and an edge from each state to the end node.")
HTML('<div class="alert alert-block alert-success">Your HMM network topology looks good!</div>')

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, basic_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, basic_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))

assert hmm_training_acc > 0.97, "Uh oh. Your HMM accuracy on the training set doesn't look right."
assert hmm_testing_acc > 0.955, "Uh oh. Your HMM accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your HMM tagger accuracy looks correct! Congratulations, you\'ve finished the project.</div>')

# %% [markdown]
# ### Example Decoding Sequences with the HMM Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, basic_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")

# %% [markdown]
# ## Finishing the project
# ---
#
# <div class="alert alert-block alert-info">
# **Note:** **SAVE YOUR NOTEBOOK**, then run the next cell to generate an HTML copy. You will zip & submit both this file and the HTML copy for review.
# </div>

# %%
# !!jupyter nbconvert *.ipynb

# %% [markdown]
# ## Step 4: [Optional] Improving model performance
# ---
# There are additional enhancements that can be incorporated into your tagger that improve performance on larger tagsets where the data sparsity problem is more significant. The data sparsity problem arises because the same amount of data split over more tags means there will be fewer samples in each tag, and there will be more missing data  tags that have zero occurrences in the data. The techniques in this section are optional.
#
# - [Laplace Smoothing](https://en.wikipedia.org/wiki/Additive_smoothing) (pseudocounts)
#     Laplace smoothing is a technique where you add a small, non-zero value to all observed counts to offset for unobserved values.
#
# - Backoff Smoothing
#     Another smoothing technique is to interpolate between n-grams for missing data. This method is more effective than Laplace smoothing at combatting the data sparsity problem. Refer to chapters 4, 9, and 10 of the [Speech & Language Processing](https://web.stanford.edu/~jurafsky/slp3/) book for more information.
#
# - Extending to Trigrams
#     HMM taggers have achieved better than 96% accuracy on this dataset with the full Penn treebank tagset using an architecture described in [this](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf) paper. Altering your HMM to achieve the same performance would require implementing deleted interpolation (described in the paper), incorporating trigram probabilities in your frequency tables, and re-implementing the Viterbi algorithm to consider three consecutive states instead of two.
#
# ### Obtain the Brown Corpus with a Larger Tagset
# Run the code below to download a copy of the brown corpus with the full NLTK tagset. You will need to research the available tagset information in the NLTK docs and determine the best way to extract the subset of NLTK tags you want to explore. If you write the following the format specified in Step 1, then you can reload the data using all of the code above for comparison.
#
# Refer to [Chapter 5](http://www.nltk.org/book/ch05.html) of the NLTK book for more information on the available tagsets.

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import brown

nltk.download('brown')
training_corpus = nltk.corpus.brown
training_corpus.tagged_sents()[0]
